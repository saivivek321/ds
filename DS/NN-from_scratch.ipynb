# %%
                                                        #Name - Rajat Goyal
                                                        #Section - B
                                                        #Roll No.- 197267

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def relu(z):
    a = np.maximum(0,z)
    return a

def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
#Question 1
#predict the values for Boston House prices dataset
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03
layer_sizes=[13,5,5,1]
df =  pd.read_csv('boston.csv')
df.head()
n=df.shape[1]               # n--> number of columns
m=df.shape[0]               # m--> number of rows

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      # we take 90% of rows in training data
y_train=np.array(df.iloc[:int(0.9*m),-1])        # only the last column is in y_train  
x_test=np.array(df.iloc[int(0.9*m):,:n-1])       # only 10 % of rows is in testing dataset
y_test=np.array(df.iloc[int(0.9*m):,-1])         # splitting into training and testing dataset 
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)
print(y_predict)
# Out:
# Cost at iteration 1 = 308.32960526128124
#
# Cost at iteration 2 = 308.2935309748525
#
# Cost at iteration 3 = 308.2575020554358
#
# Cost at iteration 4 = 308.2215046789314
#
# Cost at iteration 5 = 308.1855153249217
#
# Cost at iteration 6 = 308.14951635213816
#
# Cost at iteration 7 = 308.1135069053736
#
# Cost at iteration 8 = 308.0774310839003
#
# Cost at iteration 9 = 308.0412734968804
#
# Cost at iteration 10 = 308.0050468234955
#
# Cost at iteration 11 = 307.9687019817939
#
# Cost at iteration 12 = 307.9322827019505
#
# Cost at iteration 13 = 307.8958322669722
#
# Cost at iteration 14 = 307.85935102320497
#
# Cost at iteration 15 = 307.82283536258836
#
# Cost at iteration 16 = 307.78627942972685
#
# Cost at iteration 17 = 307.74967828629946
#
# Cost at iteration 18 = 307.71302802682214
#
# Cost at iteration 19 = 307.67632510392855
#
# Cost at iteration 20 = 307.6395632829888
#
# Cost at iteration 21 = 307.60273869749244
#
# Cost at iteration 22 = 307.56585376104255
#
# Cost at iteration 23 = 307.52891686213854
#
# Cost at iteration 24 = 307.49190308708853
#
# Cost at iteration 25 = 307.4547919195715
#
# Cost at iteration 26 = 307.4175741994697
#
# Cost at iteration 27 = 307.38024741635036
#
# Cost at iteration 28 = 307.3428088083703
#
# Cost at iteration 29 = 307.3052587175789
#
# Cost at iteration 30 = 307.26758606405184
#
# Cost at iteration 31 = 307.22977355464445
#
# Cost at iteration 32 = 307.1918307782802
#
# Cost at iteration 33 = 307.153763463605
#
# Cost at iteration 34 = 307.1155541090086
#
# Cost at iteration 35 = 307.0771876859206
#
# Cost at iteration 36 = 307.0386408517211
#
# Cost at iteration 37 = 306.9998891425831
#
# Cost at iteration 38 = 306.9608937679422
#
# Cost at iteration 39 = 306.9216354670291
#
# Cost at iteration 40 = 306.88208737707697
#
# Cost at iteration 41 = 306.8422201436715
#
# Cost at iteration 42 = 306.8020031735029
#
# Cost at iteration 43 = 306.7613995103436
#
# Cost at iteration 44 = 306.7203785536417
#
# Cost at iteration 45 = 306.6789062488356
#
# Cost at iteration 46 = 306.63694217986676
#
# Cost at iteration 47 = 306.59444066012526
#
# Cost at iteration 48 = 306.55134928125904
#
# Cost at iteration 49 = 306.5076094539278
#
# Cost at iteration 50 = 306.46315815797897
#
# Cost at iteration 51 = 306.4179238234781
#
# Cost at iteration 52 = 306.3718264644051
#
# Cost at iteration 53 = 306.3247776204162
#
# Cost at iteration 54 = 306.27667253985163
#
# Cost at iteration 55 = 306.22739673595987
#
# Cost at iteration 56 = 306.1768247291293
#
# Cost at iteration 57 = 306.1248085307065
#
# Cost at iteration 58 = 306.0711799320299
#
# Cost at iteration 59 = 306.0157476929529
#
# Cost at iteration 60 = 305.95829559664367
#
# Cost at iteration 61 = 305.89857804159595
#
# Cost at iteration 62 = 305.83631604404934
#
# Cost at iteration 63 = 305.77117951701734
#
# Cost at iteration 64 = 305.7027917640488
#
# Cost at iteration 65 = 305.6307156011425
#
# Cost at iteration 66 = 305.5544374933356
#
# Cost at iteration 67 = 305.47335771326
#
# Cost at iteration 68 = 305.3867731617811
#
# Cost at iteration 69 = 305.2938562924334
#
# Cost at iteration 70 = 305.1936240595064
#
# Cost at iteration 71 = 305.08490705537736
#
# Cost at iteration 72 = 304.9663060191916
#
# Cost at iteration 73 = 304.8361388423604
#
# Cost at iteration 74 = 304.6923715422294
#
# Cost at iteration 75 = 304.53253145638854
#
# Cost at iteration 76 = 304.35359296892483
#
# Cost at iteration 77 = 304.1518302952664
#
# Cost at iteration 78 = 303.9226223861742
#
# Cost at iteration 79 = 303.66019595346216
#
# Cost at iteration 80 = 303.3572798795707
#
# Cost at iteration 81 = 303.0046392331068
#
# Cost at iteration 82 = 302.5904412516337
#
# Cost at iteration 83 = 302.09937986366316
#
# Cost at iteration 84 = 301.5114447164875
#
# Cost at iteration 85 = 300.80019772263773
#
# Cost at iteration 86 = 299.9302912969214
#
# Cost at iteration 87 = 298.85387775526783
#
# Cost at iteration 88 = 297.5053636653808
#
# Cost at iteration 89 = 295.7935786909425
#
# Cost at iteration 90 = 293.59001622321506
#
# Cost at iteration 91 = 290.7109858840444
#
# Cost at iteration 92 = 286.89044915696564
#
# Cost at iteration 93 = 281.73885967622283
#
# Cost at iteration 94 = 274.6823405146314
#
# Cost at iteration 95 = 264.87836996627505
#
# Cost at iteration 96 = 251.11982770479818
#
# Cost at iteration 97 = 231.79304563152866
#
# Cost at iteration 98 = 205.11672205433132
#
# Cost at iteration 99 = 170.2204729906084
#
# Cost at iteration 100 = 129.7925637917758
#
# Cost at iteration 101 = 92.96622547873227
#
# Cost at iteration 102 = 70.95818357850777
#
# Cost at iteration 103 = 63.745348436637975
#
# Cost at iteration 104 = 62.06334211813834
#
# Cost at iteration 105 = 61.17158708296728
#
# Cost at iteration 106 = 60.353983151428494
#
# Cost at iteration 107 = 59.56381119831374
#
# Cost at iteration 108 = 58.7981098049364
#
# Cost at iteration 109 = 58.05590760284752
#
# Cost at iteration 110 = 57.33641295279149
#
# Cost at iteration 111 = 56.63893099377235
#
# Cost at iteration 112 = 55.9628497349485
#
# Cost at iteration 113 = 55.30762981469866
#
# Cost at iteration 114 = 54.6727970859628
#
# Cost at iteration 115 = 54.0579342648643
#
# Cost at iteration 116 = 53.462672998706175
#
# Cost at iteration 117 = 52.88668639978349
#
# Cost at iteration 118 = 52.32968519227757
#
# Cost at iteration 119 = 51.791409211867375
#
# Cost at iteration 120 = 51.2716223413912
#
# Cost at iteration 121 = 50.7701071084936
#
# Cost at iteration 122 = 50.28665953421463
#
# Cost at iteration 123 = 49.821083733057826
#
# Cost at iteration 124 = 49.37318873502624
#
# Cost at iteration 125 = 48.9427832159961
#
# Cost at iteration 126 = 48.52967151208469
#
# Cost at iteration 127 = 48.13363303888686
#
# Cost at iteration 128 = 47.75441189817132
#
# Cost at iteration 129 = 47.391799815880645
#
# Cost at iteration 130 = 47.045559581099276
#
# Cost at iteration 131 = 46.715389616546574
#
# Cost at iteration 132 = 46.400993034171464
#
# Cost at iteration 133 = 46.102081611824424
#
# Cost at iteration 134 = 45.81833811609649
#
# Cost at iteration 135 = 45.54941615134998
#
# Cost at iteration 136 = 45.29494421270808
#
# Cost at iteration 137 = 45.05453397835882
#
# Cost at iteration 138 = 44.82777017235005
#
# Cost at iteration 139 = 44.61421660078933
#
# Cost at iteration 140 = 44.41343104182314
#
# Cost at iteration 141 = 44.22495252045739
#
# Cost at iteration 142 = 44.048310409764284
#
# Cost at iteration 143 = 43.88300639166973
#
# Cost at iteration 144 = 43.728534203781464
#
# Cost at iteration 145 = 43.58441339631927
#
# Cost at iteration 146 = 43.45013322817605
#
# Cost at iteration 147 = 43.32521075105155
#
# Cost at iteration 148 = 43.20915394860942
#
# Cost at iteration 149 = 43.10147328608886
#
# Cost at iteration 150 = 43.00167629593102
#
# Cost at iteration 151 = 42.90926333351842
#
# Cost at iteration 152 = 42.82379243811548
#
# Cost at iteration 153 = 42.74481854285215
#
# Cost at iteration 154 = 42.67191416065813
#
# Cost at iteration 155 = 42.60466147122744
#
# Cost at iteration 156 = 42.542657667850555
#
# Cost at iteration 157 = 42.485518966592245
#
# Cost at iteration 158 = 42.432879955314185
#
# Cost at iteration 159 = 42.38439364845968
#
# Cost at iteration 160 = 42.33973144525467
#
# Cost at iteration 161 = 42.29858594511025
#
# Cost at iteration 162 = 42.26066750784773
#
# Cost at iteration 163 = 42.22570481659129
#
# Cost at iteration 164 = 42.193444642013056
#
# Cost at iteration 165 = 42.16365164026086
#
# Cost at iteration 166 = 42.13610695347516
#
# Cost at iteration 167 = 42.11060788271486
#
# Cost at iteration 168 = 42.086967301034704
#
# Cost at iteration 169 = 42.065009611181665
#
# Cost at iteration 170 = 42.044562928660454
#
# Cost at iteration 171 = 42.025499414548214
#
# Cost at iteration 172 = 42.00768640472212
#
# Cost at iteration 173 = 41.991002501867236
#
# Cost at iteration 174 = 41.97533701267064
#
# Cost at iteration 175 = 41.960589181652
#
# Cost at iteration 176 = 41.94666745196321
#
# Cost at iteration 177 = 41.93348875516627
#
# Cost at iteration 178 = 41.92097784086448
#
# Cost at iteration 179 = 41.90906663695707
#
# Cost at iteration 180 = 41.89769364604081
#
# Cost at iteration 181 = 41.88680337889209
#
# Cost at iteration 182 = 41.87634582850496
#
# Cost at iteration 183 = 41.866275979022994
#
# Cost at iteration 184 = 41.85655335031314
#
# Cost at iteration 185 = 41.8471415770026
#
# Cost at iteration 186 = 41.838008020550305
#
# Cost at iteration 187 = 41.82871072920386
#
# Cost at iteration 188 = 41.818364157217296
#
# Cost at iteration 189 = 41.808302704550776
#
# Cost at iteration 190 = 41.79850276636064
#
# Cost at iteration 191 = 41.788741515078144
#
# Cost at iteration 192 = 41.778774977267005
#
# Cost at iteration 193 = 41.76904029707972
#
# Cost at iteration 194 = 41.759431612730864
#
# Cost at iteration 195 = 41.74966296057078
#
# Cost at iteration 196 = 41.74009888008254
#
# Cost at iteration 197 = 41.73072545637689
#
# Cost at iteration 198 = 41.72152952915667
#
# Cost at iteration 199 = 41.71249891493632
#
# Cost at iteration 200 = 41.70362235652713
#
# Cost at iteration 201 = 41.69488945059153
#
# Cost at iteration 202 = 41.68629057865711
#
# Cost at iteration 203 = 41.67781684360701
#
# Cost at iteration 204 = 41.669460011430765
#
# Cost at iteration 205 = 41.66121245783376
#
# Cost at iteration 206 = 41.65306718836037
#
# Cost at iteration 207 = 41.645017680680596
#
# Cost at iteration 208 = 41.63705776591891
#
# Cost at iteration 209 = 41.62906325795524
#
# Cost at iteration 210 = 41.62102920508308
#
# Cost at iteration 211 = 41.61301110023259
#
# Cost at iteration 212 = 41.60502340222297
#
# Cost at iteration 213 = 41.59711759779142
#
# Cost at iteration 214 = 41.58928929313
#
# Cost at iteration 215 = 41.58153416832977
#
# Cost at iteration 216 = 41.57384825603802
#
# Cost at iteration 217 = 41.56622793474511
#
# Cost at iteration 218 = 41.558669508244456
#
# Cost at iteration 219 = 41.55116964728822
#
# Cost at iteration 220 = 41.54372522215118
#
# Cost at iteration 221 = 41.53633329012141
#
# Cost at iteration 222 = 41.528991083446094
#
# Cost at iteration 223 = 41.52169599800026
#
# Cost at iteration 224 = 41.51444558274657
#
# Cost at iteration 225 = 41.50723752993683
#
# Cost at iteration 226 = 41.50006966599961
#
# Cost at iteration 227 = 41.49294000333522
#
# Cost at iteration 228 = 41.48584663268994
#
# Cost at iteration 229 = 41.478787668694096
#
# Cost at iteration 230 = 41.471761410935734
#
# Cost at iteration 231 = 41.464766212068604
#
# Cost at iteration 232 = 41.4578006138088
#
# Cost at iteration 233 = 41.4508631030729
#
# Cost at iteration 234 = 41.443940203565546
#
# Cost at iteration 235 = 41.43702422658769
#
# Cost at iteration 236 = 41.43013412348179
#
# Cost at iteration 237 = 41.423268754588634
#
# Cost at iteration 238 = 41.41642698470823
#
# Cost at iteration 239 = 41.409607733869144
#
# Cost at iteration 240 = 41.40280997869149
#
# Cost at iteration 241 = 41.39603274958933
#
# Cost at iteration 242 = 41.389275127783456
#
# Cost at iteration 243 = 41.38253624246161
#
# Cost at iteration 244 = 41.37581526810517
#
# Cost at iteration 245 = 41.36911142197382
#
# Cost at iteration 246 = 41.362423961738365
#
# Cost at iteration 247 = 41.355752321982564
#
# Cost at iteration 248 = 41.349095733542455
#
# Cost at iteration 249 = 41.342453526021345
#
# Cost at iteration 250 = 41.33582509843696
#
# Cost at iteration 251 = 41.32920987965248
#
# Cost at iteration 252 = 41.322607342163636
#
# Cost at iteration 253 = 41.316016964359896
#
# Cost at iteration 254 = 41.309438248064126
#
# Cost at iteration 255 = 41.30287072886548
#
# Cost at iteration 256 = 41.29631396501669
#
# Cost at iteration 257 = 41.28976753659007
#
# Cost at iteration 258 = 41.28323104434138
#
# Cost at iteration 259 = 41.276704108607994
#
# Cost at iteration 260 = 41.27018636826588
#
# Cost at iteration 261 = 41.26367714176513
#
# Cost at iteration 262 = 41.25717625714992
#
# Cost at iteration 263 = 41.25068345398946
#
# Cost at iteration 264 = 41.24419854999741
#
# Cost at iteration 265 = 41.237721266021154
#
# Cost at iteration 266 = 41.23125130703556
#
# Cost at iteration 267 = 41.22478773158048
#
# Cost at iteration 268 = 41.21833099549482
#
# Cost at iteration 269 = 41.211880867784096
#
# Cost at iteration 270 = 41.205437126750454
#
# Cost at iteration 271 = 41.19899956077829
#
# Cost at iteration 272 = 41.19256796791064
#
# Cost at iteration 273 = 41.186142155353764
#
# Cost at iteration 274 = 41.179721939000686
#
# Cost at iteration 275 = 41.17330714297946
#
# Cost at iteration 276 = 41.16689759922551
#
# Cost at iteration 277 = 41.16049314707663
#
# Cost at iteration 278 = 41.15409363288954
#
# Cost at iteration 279 = 41.14769890967679
#
# Cost at iteration 280 = 41.14130914724387
#
# Cost at iteration 281 = 41.134924070193016
#
# Cost at iteration 282 = 41.12854340994073
#
# Cost at iteration 283 = 41.122167018088405
#
# Cost at iteration 284 = 41.1157947771109
#
# Cost at iteration 285 = 41.10942657343349
#
# Cost at iteration 286 = 41.10306229801092
#
# Cost at iteration 287 = 41.09670184615596
#
# Cost at iteration 288 = 41.09034521896558
#
# Cost at iteration 289 = 41.083992262533975
#
# Cost at iteration 290 = 41.077642842786794
#
# Cost at iteration 291 = 41.071296934508084
#
# Cost at iteration 292 = 41.06495438513538
#
# Cost at iteration 293 = 41.0586151147713
#
# Cost at iteration 294 = 41.05227904382826
#
# Cost at iteration 295 = 41.04594609539223
#
# Cost at iteration 296 = 41.03961619526617
#
# Cost at iteration 297 = 41.03328952373996
#
# Cost at iteration 298 = 41.02696582397003
#
# Cost at iteration 299 = 41.0206450817424
#
# Cost at iteration 300 = 41.01432711789512
#
# Cost at iteration 301 = 41.00801187240193
#
# Cost at iteration 302 = 41.00169928500065
#
# Cost at iteration 303 = 40.99538929717413
#
# Cost at iteration 304 = 40.98908196750018
#
# Cost at iteration 305 = 40.982765586336164
#
# Cost at iteration 306 = 40.97645133406669
#
# Cost at iteration 307 = 40.970138904141635
#
# Cost at iteration 308 = 40.96382858250426
#
# Cost at iteration 309 = 40.957520730110765
#
# Cost at iteration 310 = 40.95121492153581
#
# Cost at iteration 311 = 40.944911093627574
#
# Cost at iteration 312 = 40.93860920902548
#
# Cost at iteration 313 = 40.932309289236954
#
# Cost at iteration 314 = 40.926011601112506
#
# Cost at iteration 315 = 40.91971599710689
#
# Cost at iteration 316 = 40.91342268378853
#
# Cost at iteration 317 = 40.90713118442445
#
# Cost at iteration 318 = 40.90084175777592
#
# Cost at iteration 319 = 40.8945543878735
#
# Cost at iteration 320 = 40.88826870177003
#
# Cost at iteration 321 = 40.881984754562104
#
# Cost at iteration 322 = 40.87570291663164
#
# Cost at iteration 323 = 40.86942267395008
#
# Cost at iteration 324 = 40.86314403301665
#
# Cost at iteration 325 = 40.85686693324354
#
# Cost at iteration 326 = 40.85059134179626
#
# Cost at iteration 327 = 40.84431723725741
#
# Cost at iteration 328 = 40.83804464222985
#
# Cost at iteration 329 = 40.83177370244271
#
# Cost at iteration 330 = 40.82550464637557
#
# Cost at iteration 331 = 40.81923696016178
#
# Cost at iteration 332 = 40.81297062104472
#
# Cost at iteration 333 = 40.80670560223084
#
# Cost at iteration 334 = 40.800441876973984
#
# Cost at iteration 335 = 40.79417941882131
#
# Cost at iteration 336 = 40.78791821475054
#
# Cost at iteration 337 = 40.781658240869746
#
# Cost at iteration 338 = 40.77539967546313
#
# Cost at iteration 339 = 40.769142396131606
#
# Cost at iteration 340 = 40.76288625871668
#
# Cost at iteration 341 = 40.7566312404385
#
# Cost at iteration 342 = 40.75037731683002
#
# Cost at iteration 343 = 40.74412477814541
#
# Cost at iteration 344 = 40.73787376151323
#
# Cost at iteration 345 = 40.73162376823565
#
# Cost at iteration 346 = 40.7253749021588
#
# Cost at iteration 347 = 40.71912723182158
#
# Cost at iteration 348 = 40.71288111805572
#
# Cost at iteration 349 = 40.70663616826954
#
# Cost at iteration 350 = 40.70039217631455
#
# Cost at iteration 351 = 40.694149088255365
#
# Cost at iteration 352 = 40.6879068836817
#
# Cost at iteration 353 = 40.68166554034569
#
# Cost at iteration 354 = 40.67539380103095
#
# Cost at iteration 355 = 40.66911049231062
#
# Cost at iteration 356 = 40.662827762213354
#
# Cost at iteration 357 = 40.65654615498192
#
# Cost at iteration 358 = 40.650264914184845
#
# Cost at iteration 359 = 40.64398404118949
#
# Cost at iteration 360 = 40.63770352753379
#
# Cost at iteration 361 = 40.631423363680625
#
# Cost at iteration 362 = 40.625143539520465
#
# Cost at iteration 363 = 40.61886403785305
#
# Cost at iteration 364 = 40.61258479915035
#
# Cost at iteration 365 = 40.60630586399974
#
# Cost at iteration 366 = 40.600027223360904
#
# Cost at iteration 367 = 40.59374886502782
#
# Cost at iteration 368 = 40.58747077629832
#
# Cost at iteration 369 = 40.58119294413356
#
# Cost at iteration 370 = 40.574915355188736
#
# Cost at iteration 371 = 40.5686379958362
#
# Cost at iteration 372 = 40.56236093968317
#
# Cost at iteration 373 = 40.556084112111144
#
# Cost at iteration 374 = 40.54980747323885
#
# Cost at iteration 375 = 40.54353100945829
#
# Cost at iteration 376 = 40.5372547060642
#
# Cost at iteration 377 = 40.530978548138584
#
# Cost at iteration 378 = 40.524702520606574
#
# Cost at iteration 379 = 40.518426608252504
#
# Cost at iteration 380 = 40.51215072168498
#
# Cost at iteration 381 = 40.50587481867465
#
# Cost at iteration 382 = 40.499598944197736
#
# Cost at iteration 383 = 40.49332305217905
#
# Cost at iteration 384 = 40.48704718706762
#
# Cost at iteration 385 = 40.480771340395755
#
# Cost at iteration 386 = 40.47449509237568
#
# Cost at iteration 387 = 40.46821726128111
#
# Cost at iteration 388 = 40.46193937661901
#
# Cost at iteration 389 = 40.455661425386765
#
# Cost at iteration 390 = 40.449383391688194
#
# Cost at iteration 391 = 40.44310525948293
#
# Cost at iteration 392 = 40.436827012706196
#
# Cost at iteration 393 = 40.43054863247183
#
# Cost at iteration 394 = 40.424270085990685
#
# Cost at iteration 395 = 40.417991500659056
#
# Cost at iteration 396 = 40.41171279558423
#
# Cost at iteration 397 = 40.405421838952165
#
# Cost at iteration 398 = 40.399123554783706
#
# Cost at iteration 399 = 40.39282476991221
#
# Cost at iteration 400 = 40.38652550162372
#
# Cost at iteration 401 = 40.38022574398602
#
# Cost at iteration 402 = 40.373925489708455
#
# Cost at iteration 403 = 40.36762388219994
#
# Cost at iteration 404 = 40.36132042496182
#
# Cost at iteration 405 = 40.35501635246781
#
# Cost at iteration 406 = 40.34871172125483
#
# Cost at iteration 407 = 40.342406526394605
#
# Cost at iteration 408 = 40.33610075822628
#
# Cost at iteration 409 = 40.329794406617
#
# Cost at iteration 410 = 40.32348752417008
#
# Cost at iteration 411 = 40.31718038118719
#
# Cost at iteration 412 = 40.31087260712891
#
# Cost at iteration 413 = 40.304565378405016
#
# Cost at iteration 414 = 40.29825754262949
#
# Cost at iteration 415 = 40.29194909498046
#
# Cost at iteration 416 = 40.28563999998096
#
# Cost at iteration 417 = 40.27933024841111
#
# Cost at iteration 418 = 40.27301982803584
#
# Cost at iteration 419 = 40.26670872641577
#
# Cost at iteration 420 = 40.2603973625714
#
# Cost at iteration 421 = 40.25408809201447
#
# Cost at iteration 422 = 40.2477783002622
#
# Cost at iteration 423 = 40.24146778851915
#
# Cost at iteration 424 = 40.23515639616512
#
# Cost at iteration 425 = 40.22884409589634
#
# Cost at iteration 426 = 40.22253103526554
#
# Cost at iteration 427 = 40.216217205217255
#
# Cost at iteration 428 = 40.20990283507548
#
# Cost at iteration 429 = 40.203587756288904
#
# Cost at iteration 430 = 40.19727187167956
#
# Cost at iteration 431 = 40.19095517052864
#
# Cost at iteration 432 = 40.18463573527457
#
# Cost at iteration 433 = 40.17831564615457
#
# Cost at iteration 434 = 40.17199448242806
#
# Cost at iteration 435 = 40.16567243595435
#
# Cost at iteration 436 = 40.159349496327884
#
# Cost at iteration 437 = 40.15302565079862
#
# Cost at iteration 438 = 40.14670088658278
#
# Cost at iteration 439 = 40.14037519090943
#
# Cost at iteration 440 = 40.13404855102577
#
# Cost at iteration 441 = 40.127720954201365
#
# Cost at iteration 442 = 40.12139238773216
#
# Cost at iteration 443 = 40.115062838944105
#
# Cost at iteration 444 = 40.10873229519682
#
# Cost at iteration 445 = 40.10240074388676
#
# Cost at iteration 446 = 40.09606790579633
#
# Cost at iteration 447 = 40.08973399169358
#
# Cost at iteration 448 = 40.08339898853915
#
# Cost at iteration 449 = 40.07706248122968
#
# Cost at iteration 450 = 40.07072489707464
#
# Cost at iteration 451 = 40.06438557193747
#
# Cost at iteration 452 = 40.058043471572304
#
# Cost at iteration 453 = 40.05170033755581
#
# Cost at iteration 454 = 40.04535606006569
#
# Cost at iteration 455 = 40.03897023752834
#
# Cost at iteration 456 = 40.03258116694812
#
# Cost at iteration 457 = 40.02619056627451
#
# Cost at iteration 458 = 40.0197984482015
#
# Cost at iteration 459 = 40.01340481532358
#
# Cost at iteration 460 = 40.007008584442026
#
# Cost at iteration 461 = 40.000610632638576
#
# Cost at iteration 462 = 39.99421185717229
#
# Cost at iteration 463 = 39.98781170802615
#
# Cost at iteration 464 = 39.981410028545874
#
# Cost at iteration 465 = 39.975006928377745
#
# Cost at iteration 466 = 39.96860295871185
#
# Cost at iteration 467 = 39.96219752169398
#
# Cost at iteration 468 = 39.955790552775525
#
# Cost at iteration 469 = 39.949382049224795
#
# Cost at iteration 470 = 39.94297237010745
#
# Cost at iteration 471 = 39.93656121981196
#
# Cost at iteration 472 = 39.93014852703938
#
# Cost at iteration 473 = 39.92373428714544
#
# Cost at iteration 474 = 39.9173184944266
#
# Cost at iteration 475 = 39.910901142906035
#
# Cost at iteration 476 = 39.90448218315803
#
# Cost at iteration 477 = 39.89806156294729
#
# Cost at iteration 478 = 39.89163886393108
#
# Cost at iteration 479 = 39.8852145703464
#
# Cost at iteration 480 = 39.87878852352555
#
# Cost at iteration 481 = 39.87235898257844
#
# Cost at iteration 482 = 39.86592748170464
#
# Cost at iteration 483 = 39.85949438572772
#
# Cost at iteration 484 = 39.8530597164791
#
# Cost at iteration 485 = 39.846623386714384
#
# Cost at iteration 486 = 39.84018511152605
#
# Cost at iteration 487 = 39.833745434415405
#
# Cost at iteration 488 = 39.82730406556473
#
# Cost at iteration 489 = 39.82086100812017
#
# Cost at iteration 490 = 39.81441625385086
#
# Cost at iteration 491 = 39.80796921269595
#
# Cost at iteration 492 = 39.80152042376563
#
# Cost at iteration 493 = 39.795070333944714
#
# Cost at iteration 494 = 39.788618569519386
#
# Cost at iteration 495 = 39.78216519795726
#
# Cost at iteration 496 = 39.77571008446423
#
# Cost at iteration 497 = 39.76925322520994
#
# Cost at iteration 498 = 39.76279490380677
#
# Cost at iteration 499 = 39.756335107283554
#
# Cost at iteration 500 = 39.749873539526874
#
# Cost at iteration 501 = 39.74341019643358
#
# Cost at iteration 502 = 39.73694506954743
#
# Cost at iteration 503 = 39.73047810724253
#
# Cost at iteration 504 = 39.72400955710893
#
# Cost at iteration 505 = 39.71753944688831
#
# Cost at iteration 506 = 39.711067524327945
#
# Cost at iteration 507 = 39.704593785283876
#
# Cost at iteration 508 = 39.69811822127133
#
# Cost at iteration 509 = 39.691640804695865
#
# Cost at iteration 510 = 39.68516135909056
#
# Cost at iteration 511 = 39.67867979762982
#
# Cost at iteration 512 = 39.67219538045875
#
# Cost at iteration 513 = 39.66570908306151
#
# Cost at iteration 514 = 39.659220997255645
#
# Cost at iteration 515 = 39.652731988070904
#
# Cost at iteration 516 = 39.64624137568115
#
# Cost at iteration 517 = 39.6397492061296
#
# Cost at iteration 518 = 39.63325537973659
#
# Cost at iteration 519 = 39.62675964929575
#
# Cost at iteration 520 = 39.6202620140803
#
# Cost at iteration 521 = 39.6137624658503
#
# Cost at iteration 522 = 39.60726152711174
#
# Cost at iteration 523 = 39.60076267720903
#
# Cost at iteration 524 = 39.59426462147327
#
# Cost at iteration 525 = 39.587764391395474
#
# Cost at iteration 526 = 39.581262429521495
#
# Cost at iteration 527 = 39.57475955894798
#
# Cost at iteration 528 = 39.56825360517916
#
# Cost at iteration 529 = 39.56174424651514
#
# Cost at iteration 530 = 39.55523294423847
#
# Cost at iteration 531 = 39.54871975094814
#
# Cost at iteration 532 = 39.54220462309638
#
# Cost at iteration 533 = 39.53568753829347
#
# Cost at iteration 534 = 39.52914364240129
#
# Cost at iteration 535 = 39.52255741485013
#
# Cost at iteration 536 = 39.51596855739386
#
# Cost at iteration 537 = 39.50937752668511
#
# Cost at iteration 538 = 39.502784189314575
#
# Cost at iteration 539 = 39.496188444262536
#
# Cost at iteration 540 = 39.489579941438315
#
# Cost at iteration 541 = 39.48292987668084
#
# Cost at iteration 542 = 39.47627734609401
#
# Cost at iteration 543 = 39.46962223680893
#
# Cost at iteration 544 = 39.46296471710878
#
# Cost at iteration 545 = 39.45630560489395
#
# Cost at iteration 546 = 39.44964404892991
#
# Cost at iteration 547 = 39.44297995780862
#
# Cost at iteration 548 = 39.436313338774774
#
# Cost at iteration 549 = 39.42964419778363
#
# Cost at iteration 550 = 39.422972164498574
#
# Cost at iteration 551 = 39.41629747438357
#
# Cost at iteration 552 = 39.40962032726796
#
# Cost at iteration 553 = 39.40294067498446
#
# Cost at iteration 554 = 39.396258518984126
#
# Cost at iteration 555 = 39.3895740143527
#
# Cost at iteration 556 = 39.38288739607972
#
# Cost at iteration 557 = 39.37619830072647
#
# Cost at iteration 558 = 39.36950697327834
#
# Cost at iteration 559 = 39.36281318421703
#
# Cost at iteration 560 = 39.35611690609657
#
# Cost at iteration 561 = 39.34941888116184
#
# Cost at iteration 562 = 39.34271888270637
#
# Cost at iteration 563 = 39.33601678308611
#
# Cost at iteration 564 = 39.32931263331097
#
# Cost at iteration 565 = 39.32260601530145
#
# Cost at iteration 566 = 39.31589330664216
#
# Cost at iteration 567 = 39.30917567996074
#
# Cost at iteration 568 = 39.30245613204077
#
# Cost at iteration 569 = 39.29573406064921
#
# Cost at iteration 570 = 39.289009455339546
#
# Cost at iteration 571 = 39.28228231426816
#
# Cost at iteration 572 = 39.275558833937616
#
# Cost at iteration 573 = 39.26883299373299
#
# Cost at iteration 574 = 39.26210555384008
#
# Cost at iteration 575 = 39.25537565013518
#
# Cost at iteration 576 = 39.24864310898516
#
# Cost at iteration 577 = 39.24190734584099
#
# Cost at iteration 578 = 39.23516849357865
#
# Cost at iteration 579 = 39.228428081011344
#
# Cost at iteration 580 = 39.22168500544271
#
# Cost at iteration 581 = 39.2149387844327
#
# Cost at iteration 582 = 39.2081900118969
#
# Cost at iteration 583 = 39.201437452576315
#
# Cost at iteration 584 = 39.19468221814415
#
# Cost at iteration 585 = 39.18792369955886
#
# Cost at iteration 586 = 39.181163118069335
#
# Cost at iteration 587 = 39.174411115666906
#
# Cost at iteration 588 = 39.16765518306392
#
# Cost at iteration 589 = 39.160896782264494
#
# Cost at iteration 590 = 39.154135913857246
#
# Cost at iteration 591 = 39.14737257787988
#
# Cost at iteration 592 = 39.140607161912584
#
# Cost at iteration 593 = 39.13383918651634
#
# Cost at iteration 594 = 39.12707288660129
#
# Cost at iteration 595 = 39.120305332979505
#
# Cost at iteration 596 = 39.11353533073889
#
# Cost at iteration 597 = 39.10676610096697
#
# Cost at iteration 598 = 39.099995130214985
#
# Cost at iteration 599 = 39.093222234809105
#
# Cost at iteration 600 = 39.08644956237355
#
# Cost at iteration 601 = 39.079672986327594
#
# Cost at iteration 602 = 39.07289283382276
#
# Cost at iteration 603 = 39.066121872702745
#
# Cost at iteration 604 = 39.059356498938875
#
# Cost at iteration 605 = 39.05259003930056
#
# Cost at iteration 606 = 39.04582176145341
#
# Cost at iteration 607 = 39.039051198981745
#
# Cost at iteration 608 = 39.03227836178478
#
# Cost at iteration 609 = 39.025502232489025
#
# Cost at iteration 610 = 39.018724651361254
#
# Cost at iteration 611 = 39.01194445460286
#
# Cost at iteration 612 = 39.00516346080267
#
# Cost at iteration 613 = 38.99838065561091
#
# Cost at iteration 614 = 38.99159560166976
#
# Cost at iteration 615 = 38.98480830350978
#
# Cost at iteration 616 = 38.97801585497998
#
# Cost at iteration 617 = 38.97121091207088
#
# Cost at iteration 618 = 38.964403527169594
#
# Cost at iteration 619 = 38.95759378640534
#
# Cost at iteration 620 = 38.95078185149741
#
# Cost at iteration 621 = 38.9439674543757
#
# Cost at iteration 622 = 38.93714998031374
#
# Cost at iteration 623 = 38.93032901825626
#
# Cost at iteration 624 = 38.92350712074189
#
# Cost at iteration 625 = 38.91668420299552
#
# Cost at iteration 626 = 38.90987771721937
#
# Cost at iteration 627 = 38.903072319852214
#
# Cost at iteration 628 = 38.896265547238244
#
# Cost at iteration 629 = 38.88945649056141
#
# Cost at iteration 630 = 38.882656737962705
#
# Cost at iteration 631 = 38.875847734012645
#
# Cost at iteration 632 = 38.8690141776345
#
# Cost at iteration 633 = 38.8622089148989
#
# Cost at iteration 634 = 38.85541974567503
#
# Cost at iteration 635 = 38.84862599267879
#
# Cost at iteration 636 = 38.84183048497432
#
# Cost at iteration 637 = 38.83503706525599
#
# Cost at iteration 638 = 38.82826050473862
#
# Cost at iteration 639 = 38.82150680913622
#
# Cost at iteration 640 = 38.81477213568973
#
# Cost at iteration 641 = 38.808037088532544
#
# Cost at iteration 642 = 38.80129358037238
#
# Cost at iteration 643 = 38.794537345709045
#
# Cost at iteration 644 = 38.78780884215092
#
# Cost at iteration 645 = 38.7811445061615
#
# Cost at iteration 646 = 38.7744856978855
#
# Cost at iteration 647 = 38.76785629131362
#
# Cost at iteration 648 = 38.761226416584776
#
# Cost at iteration 649 = 38.75459766861006
#
# Cost at iteration 650 = 38.747977462973374
#
# Cost at iteration 651 = 38.7413701750892
#
# Cost at iteration 652 = 38.73480998045869
#
# Cost at iteration 653 = 38.7282589243668
#
# Cost at iteration 654 = 38.721718503755554
#
# Cost at iteration 655 = 38.7152120869242
#
# Cost at iteration 656 = 38.70871761290686
#
# Cost at iteration 657 = 38.702272597403805
#
# Cost at iteration 658 = 38.69588943123538
#
# Cost at iteration 659 = 38.68957450702851
#
# Cost at iteration 660 = 38.68329103645893
#
# Cost at iteration 661 = 38.677023484019955
#
# Cost at iteration 662 = 38.670767825448394
#
# Cost at iteration 663 = 38.66455366454996
#
# Cost at iteration 664 = 38.65836376251491
#
# Cost at iteration 665 = 38.6521975315407
#
# Cost at iteration 666 = 38.646050629271315
#
# Cost at iteration 667 = 38.639917668098086
#
# Cost at iteration 668 = 38.63378885916192
#
# Cost at iteration 669 = 38.62768198194736
#
# Cost at iteration 670 = 38.62157929636607
#
# Cost at iteration 671 = 38.61545314573303
#
# Cost at iteration 672 = 38.609256253229105
#
# Cost at iteration 673 = 38.603060040330405
#
# Cost at iteration 674 = 38.59686576906671
#
# Cost at iteration 675 = 38.590671898265015
#
# Cost at iteration 676 = 38.58447980789225
#
# Cost at iteration 677 = 38.57829028159653
#
# Cost at iteration 678 = 38.5721026907092
#
# Cost at iteration 679 = 38.56591702778671
#
# Cost at iteration 680 = 38.55973328711663
#
# Cost at iteration 681 = 38.553551462433425
#
# Cost at iteration 682 = 38.54737154737994
#
# Cost at iteration 683 = 38.54117970291619
#
# Cost at iteration 684 = 38.53495204003405
#
# Cost at iteration 685 = 38.52872498782794
#
# Cost at iteration 686 = 38.5224985904073
#
# Cost at iteration 687 = 38.516273767191926
#
# Cost at iteration 688 = 38.5100505101345
#
# Cost at iteration 689 = 38.503827849022315
#
# Cost at iteration 690 = 38.49760640361039
#
# Cost at iteration 691 = 38.49138611179558
#
# Cost at iteration 692 = 38.485166737889905
#
# Cost at iteration 693 = 38.4789488974428
#
# Cost at iteration 694 = 38.472733984567114
#
# Cost at iteration 695 = 38.466521061765135
#
# Cost at iteration 696 = 38.460309662216325
#
# Cost at iteration 697 = 38.454099777736744
#
# Cost at iteration 698 = 38.447891402089255
#
# Cost at iteration 699 = 38.44168484825951
#
# Cost at iteration 700 = 38.43547976265713
#
# Cost at iteration 701 = 38.42927665716781
#
# Cost at iteration 702 = 38.423075255101395
#
# Cost at iteration 703 = 38.41687573764125
#
# Cost at iteration 704 = 38.41067607035343
#
# Cost at iteration 705 = 38.404477618895356
#
# Cost at iteration 706 = 38.39828042254873
#
# Cost at iteration 707 = 38.392083084476
#
# Cost at iteration 708 = 38.38588704296054
#
# Cost at iteration 709 = 38.37968334652662
#
# Cost at iteration 710 = 38.37348104968675
#
# Cost at iteration 711 = 38.36727945450993
#
# Cost at iteration 712 = 38.36107877850542
#
# Cost at iteration 713 = 38.35487945158417
#
# Cost at iteration 714 = 38.34869092849401
#
# Cost at iteration 715 = 38.342517776363614
#
# Cost at iteration 716 = 38.336346836072316
#
# Cost at iteration 717 = 38.33017802544168
#
# Cost at iteration 718 = 38.324013355925835
#
# Cost at iteration 719 = 38.317850645578176
#
# Cost at iteration 720 = 38.31168934422902
#
# Cost at iteration 721 = 38.305528796213146
#
# Cost at iteration 722 = 38.29936913948754
#
# Cost at iteration 723 = 38.29322016360644
#
# Cost at iteration 724 = 38.28707444976107
#
# Cost at iteration 725 = 38.28093028854082
#
# Cost at iteration 726 = 38.27478756816985
#
# Cost at iteration 727 = 38.26867033140753
#
# Cost at iteration 728 = 38.26255593352827
#
# Cost at iteration 729 = 38.25645430478816
#
# Cost at iteration 730 = 38.25035863342197
#
# Cost at iteration 731 = 38.24427653222481
#
# Cost at iteration 732 = 38.23822426431416
#
# Cost at iteration 733 = 38.2321879414326
#
# Cost at iteration 734 = 38.226163609175295
#
# Cost at iteration 735 = 38.22017739896437
#
# Cost at iteration 736 = 38.21419903689612
#
# Cost at iteration 737 = 38.20823393518988
#
# Cost at iteration 738 = 38.20227379486031
#
# Cost at iteration 739 = 38.19635174776223
#
# Cost at iteration 740 = 38.19045601348677
#
# Cost at iteration 741 = 38.184576361044435
#
# Cost at iteration 742 = 38.17870163344214
#
# Cost at iteration 743 = 38.172829035441886
#
# Cost at iteration 744 = 38.166991096324935
#
# Cost at iteration 745 = 38.16116571679574
#
# Cost at iteration 746 = 38.15534426026254
#
# Cost at iteration 747 = 38.14951675827046
#
# Cost at iteration 748 = 38.14371134870128
#
# Cost at iteration 749 = 38.13792810904161
#
# Cost at iteration 750 = 38.13214830032252
#
# Cost at iteration 751 = 38.12636617580317
#
# Cost at iteration 752 = 38.12058475724735
#
# Cost at iteration 753 = 38.11480521646459
#
# Cost at iteration 754 = 38.109025624768066
#
# Cost at iteration 755 = 38.10325216055246
#
# Cost at iteration 756 = 38.09747997028055
#
# Cost at iteration 757 = 38.09171709526406
#
# Cost at iteration 758 = 38.08596605889394
#
# Cost at iteration 759 = 38.080216798993945
#
# Cost at iteration 760 = 38.074456750428965
#
# Cost at iteration 761 = 38.06870595333377
#
# Cost at iteration 762 = 38.06296985439078
#
# Cost at iteration 763 = 38.05720755185466
#
# Cost at iteration 764 = 38.051424494083086
#
# Cost at iteration 765 = 38.045649138419904
#
# Cost at iteration 766 = 38.039896933867844
#
# Cost at iteration 767 = 38.03416826864582
#
# Cost at iteration 768 = 38.028461115945376
#
# Cost at iteration 769 = 38.022760320357236
#
# Cost at iteration 770 = 38.01701607372486
#
# Cost at iteration 771 = 38.011273868075534
#
# Cost at iteration 772 = 38.00549350353582
#
# Cost at iteration 773 = 37.999724195304424
#
# Cost at iteration 774 = 37.993946698366756
#
# Cost at iteration 775 = 37.988133634289326
#
# Cost at iteration 776 = 37.982339636076105
#
# Cost at iteration 777 = 37.97656105956781
#
# Cost at iteration 778 = 37.970804238376516
#
# Cost at iteration 779 = 37.96508803096862
#
# Cost at iteration 780 = 37.959378127722786
#
# Cost at iteration 781 = 37.953670894748804
#
# Cost at iteration 782 = 37.94800499955634
#
# Cost at iteration 783 = 37.942365031684226
#
# Cost at iteration 784 = 37.93672957179796
#
# Cost at iteration 785 = 37.93110385236191
#
# Cost at iteration 786 = 37.92550080975937
#
# Cost at iteration 787 = 37.91990857105064
#
# Cost at iteration 788 = 37.91431912480094
#
# Cost at iteration 789 = 37.90873686602432
#
# Cost at iteration 790 = 37.90315834462204
#
# Cost at iteration 791 = 37.89759718289427
#
# Cost at iteration 792 = 37.89204439749307
#
# Cost at iteration 793 = 37.88647433951728
#
# Cost at iteration 794 = 37.88090174598544
#
# Cost at iteration 795 = 37.87534746434762
#
# Cost at iteration 796 = 37.8697941036699
#
# Cost at iteration 797 = 37.864232654551174
#
# Cost at iteration 798 = 37.85868366463285
#
# Cost at iteration 799 = 37.85312474584274
#
# Cost at iteration 800 = 37.84743297383214
#
# Cost at iteration 801 = 37.841631350059444
#
# Cost at iteration 802 = 37.835784231825386
#
# Cost at iteration 803 = 37.82993637321518
#
# Cost at iteration 804 = 37.82405444199249
#
# Cost at iteration 805 = 37.81813997322443
#
# Cost at iteration 806 = 37.812241942470166
#
# Cost at iteration 807 = 37.8063333930011
#
# Cost at iteration 808 = 37.80041800679848
#
# Cost at iteration 809 = 37.79449789371684
#
# Cost at iteration 810 = 37.788580713638275
#
# Cost at iteration 811 = 37.782669370803696
#
# Cost at iteration 812 = 37.77676707785565
#
# Cost at iteration 813 = 37.77087601300045
#
# Cost at iteration 814 = 37.764988383948385
#
# Cost at iteration 815 = 37.759112753560814
#
# Cost at iteration 816 = 37.75322683064734
#
# Cost at iteration 817 = 37.74735469589693
#
# Cost at iteration 818 = 37.74148303503439
#
# Cost at iteration 819 = 37.73558308601859
#
# Cost at iteration 820 = 37.72963553603521
#
# Cost at iteration 821 = 37.72368662739713
#
# Cost at iteration 822 = 37.71772217410208
#
# Cost at iteration 823 = 37.71175718727987
#
# Cost at iteration 824 = 37.70578933766071
#
# Cost at iteration 825 = 37.69979288354382
#
# Cost at iteration 826 = 37.69379121092861
#
# Cost at iteration 827 = 37.68779772997056
#
# Cost at iteration 828 = 37.68180533426244
#
# Cost at iteration 829 = 37.67580683303907
#
# Cost at iteration 830 = 37.66974146775035
#
# Cost at iteration 831 = 37.66366182695492
#
# Cost at iteration 832 = 37.657578814802555
#
# Cost at iteration 833 = 37.651487488665175
#
# Cost at iteration 834 = 37.64537253227056
#
# Cost at iteration 835 = 37.63922592596248
#
# Cost at iteration 836 = 37.633064973494236
#
# Cost at iteration 837 = 37.62691426703606
#
# Cost at iteration 838 = 37.62075799551605
#
# Cost at iteration 839 = 37.614513360285734
#
# Cost at iteration 840 = 37.608231211624464
#
# Cost at iteration 841 = 37.60192143964071
#
# Cost at iteration 842 = 37.595598432201314
#
# Cost at iteration 843 = 37.58927717080893
#
# Cost at iteration 844 = 37.58295712321171
#
# Cost at iteration 845 = 37.576633483444716
#
# Cost at iteration 846 = 37.570306009855784
#
# Cost at iteration 847 = 37.56397472008814
#
# Cost at iteration 848 = 37.55763854975262
#
# Cost at iteration 849 = 37.55129679221606
#
# Cost at iteration 850 = 37.54495326445917
#
# Cost at iteration 851 = 37.53860564108706
#
# Cost at iteration 852 = 37.532249152496846
#
# Cost at iteration 853 = 37.525868316366626
#
# Cost at iteration 854 = 37.51944305865265
#
# Cost at iteration 855 = 37.513004114005696
#
# Cost at iteration 856 = 37.50656107509927
#
# Cost at iteration 857 = 37.500113936111255
#
# Cost at iteration 858 = 37.49368107698032
#
# Cost at iteration 859 = 37.487251335133095
#
# Cost at iteration 860 = 37.48083560049443
#
# Cost at iteration 861 = 37.47442647473758
#
# Cost at iteration 862 = 37.46801395947593
#
# Cost at iteration 863 = 37.461600470649294
#
# Cost at iteration 864 = 37.45518174233345
#
# Cost at iteration 865 = 37.44876682266219
#
# Cost at iteration 866 = 37.44233999035447
#
# Cost at iteration 867 = 37.43591286727753
#
# Cost at iteration 868 = 37.42945887160316
#
# Cost at iteration 869 = 37.42297368216629
#
# Cost at iteration 870 = 37.41647278820854
#
# Cost at iteration 871 = 37.40996334068429
#
# Cost at iteration 872 = 37.403409093619366
#
# Cost at iteration 873 = 37.396835378449744
#
# Cost at iteration 874 = 37.39026963135318
#
# Cost at iteration 875 = 37.383700166594274
#
# Cost at iteration 876 = 37.37706288259225
#
# Cost at iteration 877 = 37.370375641154055
#
# Cost at iteration 878 = 37.36364906887436
#
# Cost at iteration 879 = 37.356916710526775
#
# Cost at iteration 880 = 37.35018353402771
#
# Cost at iteration 881 = 37.343450266379875
#
# Cost at iteration 882 = 37.33671613897392
#
# Cost at iteration 883 = 37.3299529983549
#
# Cost at iteration 884 = 37.32316227590114
#
# Cost at iteration 885 = 37.316377462696686
#
# Cost at iteration 886 = 37.30957909497884
#
# Cost at iteration 887 = 37.302776516454564
#
# Cost at iteration 888 = 37.29597012928817
#
# Cost at iteration 889 = 37.28915989385942
#
# Cost at iteration 890 = 37.282304274358225
#
# Cost at iteration 891 = 37.27540397274877
#
# Cost at iteration 892 = 37.2684843815823
#
# Cost at iteration 893 = 37.261560558825
#
# Cost at iteration 894 = 37.254637910535074
#
# Cost at iteration 895 = 37.24771732019456
#
# Cost at iteration 896 = 37.24079243312532
#
# Cost at iteration 897 = 37.23386324094657
#
# Cost at iteration 898 = 37.22692974072052
#
# Cost at iteration 899 = 37.219991926477526
#
# Cost at iteration 900 = 37.21304979413274
#
# Cost at iteration 901 = 37.20610333859199
#
# Cost at iteration 902 = 37.19914416577408
#
# Cost at iteration 903 = 37.19215642950855
#
# Cost at iteration 904 = 37.18516142042214
#
# Cost at iteration 905 = 37.178153971804015
#
# Cost at iteration 906 = 37.171119728238054
#
# Cost at iteration 907 = 37.16408141205002
#
# Cost at iteration 908 = 37.157037503049324
#
# Cost at iteration 909 = 37.14996890227786
#
# Cost at iteration 910 = 37.1428961842045
#
# Cost at iteration 911 = 37.135819809343154
#
# Cost at iteration 912 = 37.12874580532514
#
# Cost at iteration 913 = 37.121671918154135
#
# Cost at iteration 914 = 37.114592272613166
#
# Cost at iteration 915 = 37.107483534832376
#
# Cost at iteration 916 = 37.10035417816779
#
# Cost at iteration 917 = 37.0932205283379
#
# Cost at iteration 918 = 37.0860825751097
#
# Cost at iteration 919 = 37.07894031647312
#
# Cost at iteration 920 = 37.071793745205895
#
# Cost at iteration 921 = 37.06464148560953
#
# Cost at iteration 922 = 37.05748329819349
#
# Cost at iteration 923 = 37.05032136020862
#
# Cost at iteration 924 = 37.04315148956089
#
# Cost at iteration 925 = 37.035962869034016
#
# Cost at iteration 926 = 37.028768251524454
#
# Cost at iteration 927 = 37.02156933942382
#
# Cost at iteration 928 = 37.01436612222999
#
# Cost at iteration 929 = 37.00715859797312
#
# Cost at iteration 930 = 36.999944984867156
#
# Cost at iteration 931 = 36.99271563318864
#
# Cost at iteration 932 = 36.98547764945365
#
# Cost at iteration 933 = 36.97822398837825
#
# Cost at iteration 934 = 36.97095339343176
#
# Cost at iteration 935 = 36.96367536644444
#
# Cost at iteration 936 = 36.956393014264485
#
# Cost at iteration 937 = 36.949119482117226
#
# Cost at iteration 938 = 36.9418481810985
#
# Cost at iteration 939 = 36.934567628098
#
# Cost at iteration 940 = 36.92728279112546
#
# Cost at iteration 941 = 36.919993663466755
#
# Cost at iteration 942 = 36.91270023935958
#
# Cost at iteration 943 = 36.90540232384803
#
# Cost at iteration 944 = 36.8980978979159
#
# Cost at iteration 945 = 36.89078952119929
#
# Cost at iteration 946 = 36.883487326883184
#
# Cost at iteration 947 = 36.87618089263509
#
# Cost at iteration 948 = 36.868870215302245
#
# Cost at iteration 949 = 36.86155528558515
#
# Cost at iteration 950 = 36.8542478522532
#
# Cost at iteration 951 = 36.84693697595054
#
# Cost at iteration 952 = 36.83962186894966
#
# Cost at iteration 953 = 36.832312088880414
#
# Cost at iteration 954 = 36.82501242801778
#
# Cost at iteration 955 = 36.81770858461726
#
# Cost at iteration 956 = 36.81040056211477
#
# Cost at iteration 957 = 36.80308834507967
#
# Cost at iteration 958 = 36.79579224292926
#
# Cost at iteration 959 = 36.78849996659552
#
# Cost at iteration 960 = 36.781203552730624
#
# Cost at iteration 961 = 36.77391565833468
#
# Cost at iteration 962 = 36.76662669631874
#
# Cost at iteration 963 = 36.75933360802141
#
# Cost at iteration 964 = 36.752036383830266
#
# Cost at iteration 965 = 36.7447350171038
#
# Cost at iteration 966 = 36.73742949886449
#
# Cost at iteration 967 = 36.73011982191483
#
# Cost at iteration 968 = 36.722805977621775
#
# Cost at iteration 969 = 36.71548795842764
#
# Cost at iteration 970 = 36.70816575587374
#
# Cost at iteration 971 = 36.70083936215414
#
# Cost at iteration 972 = 36.693508768883426
#
# Cost at iteration 973 = 36.686173968071905
#
# Cost at iteration 974 = 36.67883495134637
#
# Cost at iteration 975 = 36.67149171057095
#
# Cost at iteration 976 = 36.66414423734724
#
# Cost at iteration 977 = 36.65679252341524
#
# Cost at iteration 978 = 36.64943656032809
#
# Cost at iteration 979 = 36.64207633971474
#
# Cost at iteration 980 = 36.63471185306524
#
# Cost at iteration 981 = 36.62734309190533
#
# Cost at iteration 982 = 36.61997004765264
#
# Cost at iteration 983 = 36.61259271173447
#
# Cost at iteration 984 = 36.60521107549007
#
# Cost at iteration 985 = 36.59782513025122
#
# Cost at iteration 986 = 36.590434867274915
#
# Cost at iteration 987 = 36.5830402777993
#
# Cost at iteration 988 = 36.57563891543805
#
# Cost at iteration 989 = 36.56822985826168
#
# Cost at iteration 990 = 36.56081645847236
#
# Cost at iteration 991 = 36.55339870956384
#
# Cost at iteration 992 = 36.545976599912414
#
# Cost at iteration 993 = 36.5385501222076
#
# Cost at iteration 994 = 36.531119265389016
#
# Cost at iteration 995 = 36.523684021557244
#
# Cost at iteration 996 = 36.51624421265624
#
# Cost at iteration 997 = 36.508799865242274
#
# Cost at iteration 998 = 36.50135112760098
#
# Cost at iteration 999 = 36.4938968878655
#
# Cost at iteration 1000 = 36.4864371313343
#
# [[ 4.70864565]
#  [ 2.46101323]
#  [ 1.95687345]
#  [16.70821775]
#  [23.64395663]
#  [16.02693687]
#  [23.55629296]
#  [23.68180788]
#  [24.01403497]
#  [23.29318064]
#  [19.56789801]
#  [ 3.19665151]
#  [19.84979999]
#  [21.22348097]
#  [22.77188761]
#  [23.59129478]
#  [23.95616064]
#  [23.38132212]
#  [22.39310284]
#  [21.14765771]
#  [18.07628517]
#  [23.56759339]
#  [20.22767209]
#  [22.60721354]
#  [22.86693165]
#  [23.55282742]
#  [23.84792859]
#  [24.08621449]
#  [22.88536548]
#  [21.49316049]
#  [22.89672243]
#  [23.32949643]
#  [22.7755393 ]
#  [23.62744078]
#  [20.4989863 ]
#  [18.62210987]
#  [23.51660295]
#  [23.9176884 ]
#  [23.04329576]
#  [22.65051671]
#  [21.80215393]
#  [22.72442001]
#  [23.2628057 ]
#  [23.23977662]
#  [23.17906206]
#  [23.46153108]
#  [23.14392578]
#  [23.62094616]
#  [24.26173397]
#  [23.96046623]
#  [23.81424106]]

# %%
#Question 2
#predict the values for Boston House prices dataset
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03
layer_sizes=[7,5,5,1]
df =  pd.read_csv('seeds.csv')
df.head()
n=df.shape[1]               # n--> number of columns
m=df.shape[0]               # m--> number of rows

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      # we take 90% of rows in training data
y_train=np.array(df.iloc[:int(0.9*m),-1])        # only the last column is in y_train  
x_test=np.array(df.iloc[int(0.9*m):,:n-1])       # only 10 % of rows is in testing dataset
y_test=np.array(df.iloc[int(0.9*m):,-1])         # splitting into training and testing dataset 
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)
print(y_predict)
# Out:
# Cost at iteration 1 = 2.09216008017452
#
# Cost at iteration 2 = 2.0915905915911828
#
# Cost at iteration 3 = 2.091021284680014
#
# Cost at iteration 4 = 2.090452159383
#
# Cost at iteration 5 = 2.0898832156421494
#
# Cost at iteration 6 = 2.0893144533994845
#
# Cost at iteration 7 = 2.088745872597049
#
# Cost at iteration 8 = 2.088177473176905
#
# Cost at iteration 9 = 2.087609255081133
#
# Cost at iteration 10 = 2.0870412182518305
#
# Cost at iteration 11 = 2.086473362631115
#
# Cost at iteration 12 = 2.0859056881611227
#
# Cost at iteration 13 = 2.085338194784007
#
# Cost at iteration 14 = 2.0847708824419415
#
# Cost at iteration 15 = 2.0842037510771165
#
# Cost at iteration 16 = 2.0836368006317425
#
# Cost at iteration 17 = 2.0830700310480466
#
# Cost at iteration 18 = 2.0825034422682758
#
# Cost at iteration 19 = 2.081937034234696
#
# Cost at iteration 20 = 2.0813708068895886
#
# Cost at iteration 21 = 2.0808047601752566
#
# Cost at iteration 22 = 2.0802388940340215
#
# Cost at iteration 23 = 2.07967320840822
#
# Cost at iteration 24 = 2.079107703240212
#
# Cost at iteration 25 = 2.0785423784723704
#
# Cost at iteration 26 = 2.07797723404709
#
# Cost at iteration 27 = 2.0774122699067847
#
# Cost at iteration 28 = 2.0768474859938837
#
# Cost at iteration 29 = 2.0762828822508363
#
# Cost at iteration 30 = 2.0757184586201127
#
# Cost at iteration 31 = 2.0751542150441957
#
# Cost at iteration 32 = 2.074590151465592
#
# Cost at iteration 33 = 2.074026267826823
#
# Cost at iteration 34 = 2.07346256407043
#
# Cost at iteration 35 = 2.072899040138974
#
# Cost at iteration 36 = 2.0723356959750325
#
# Cost at iteration 37 = 2.0717725315212006
#
# Cost at iteration 38 = 2.0712095467200937
#
# Cost at iteration 39 = 2.070646741514345
#
# Cost at iteration 40 = 2.0700841158466052
#
# Cost at iteration 41 = 2.0695216696595446
#
# Cost at iteration 42 = 2.068959402895851
#
# Cost at iteration 43 = 2.06839731549823
#
# Cost at iteration 44 = 2.0678354074094063
#
# Cost at iteration 45 = 2.067273678572124
#
# Cost at iteration 46 = 2.0667121289291432
#
# Cost at iteration 47 = 2.0661507584232437
#
# Cost at iteration 48 = 2.065589566997223
#
# Cost at iteration 49 = 2.0650285545938982
#
# Cost at iteration 50 = 2.064467721156103
#
# Cost at iteration 51 = 2.0639070666266894
#
# Cost at iteration 52 = 2.063346590948529
#
# Cost at iteration 53 = 2.06278629406451
#
# Cost at iteration 54 = 2.0622261759175418
#
# Cost at iteration 55 = 2.0616662364505483
#
# Cost at iteration 56 = 2.0611064756064743
#
# Cost at iteration 57 = 2.0605468933282807
#
# Cost at iteration 58 = 2.0599874895589494
#
# Cost at iteration 59 = 2.0594282642414785
#
# Cost at iteration 60 = 2.0588692173188843
#
# Cost at iteration 61 = 2.058310348734202
#
# Cost at iteration 62 = 2.057751658430485
#
# Cost at iteration 63 = 2.057193146350804
#
# Cost at iteration 64 = 2.0566348124382503
#
# Cost at iteration 65 = 2.0560766566359305
#
# Cost at iteration 66 = 2.0555186788869704
#
# Cost at iteration 67 = 2.054960879134515
#
# Cost at iteration 68 = 2.0544032573217255
#
# Cost at iteration 69 = 2.053845813391783
#
# Cost at iteration 70 = 2.0532885472878863
#
# Cost at iteration 71 = 2.052731458953253
#
# Cost at iteration 72 = 2.052174548331117
#
# Cost at iteration 73 = 2.0516178153647315
#
# Cost at iteration 74 = 2.051061259997368
#
# Cost at iteration 75 = 2.0505048821723153
#
# Cost at iteration 76 = 2.0499486818328823
#
# Cost at iteration 77 = 2.049392658922393
#
# Cost at iteration 78 = 2.0488368133841917
#
# Cost at iteration 79 = 2.0482811451616407
#
# Cost at iteration 80 = 2.04772565419812
#
# Cost at iteration 81 = 2.0471703404370274
#
# Cost at iteration 82 = 2.046615203821779
#
# Cost at iteration 83 = 2.046060244295809
#
# Cost at iteration 84 = 2.04550546180257
#
# Cost at iteration 85 = 2.044950856285532
#
# Cost at iteration 86 = 2.044396427688183
#
# Cost at iteration 87 = 2.0438421759540306
#
# Cost at iteration 88 = 2.043288101026598
#
# Cost at iteration 89 = 2.0427342028494295
#
# Cost at iteration 90 = 2.042180481366085
#
# Cost at iteration 91 = 2.041626936520143
#
# Cost at iteration 92 = 2.0410735682552
#
# Cost at iteration 93 = 2.040520376514872
#
# Cost at iteration 94 = 2.0399673612427898
#
# Cost at iteration 95 = 2.039414522382606
#
# Cost at iteration 96 = 2.038861859877989
#
# Cost at iteration 97 = 2.0383093736726248
#
# Cost at iteration 98 = 2.037757063710219
#
# Cost at iteration 99 = 2.037204929934494
#
# Cost at iteration 100 = 2.03665297228919
#
# Cost at iteration 101 = 2.0361011907180684
#
# Cost at iteration 102 = 2.0355495851649024
#
# Cost at iteration 103 = 2.034998155573489
#
# Cost at iteration 104 = 2.03444690188764
#
# Cost at iteration 105 = 2.0338958240511866
#
# Cost at iteration 106 = 2.033344922007977
#
# Cost at iteration 107 = 2.032794195701878
#
# Cost at iteration 108 = 2.032243645076773
#
# Cost at iteration 109 = 2.031693270076566
#
# Cost at iteration 110 = 2.0311430706451774
#
# Cost at iteration 111 = 2.0305930467265445
#
# Cost at iteration 112 = 2.030043198264623
#
# Cost at iteration 113 = 2.029493525203388
#
# Cost at iteration 114 = 2.028944027486831
#
# Cost at iteration 115 = 2.0283947050589624
#
# Cost at iteration 116 = 2.0278455578638095
#
# Cost at iteration 117 = 2.027296585845418
#
# Cost at iteration 118 = 2.0267477889478522
#
# Cost at iteration 119 = 2.0261991671151924
#
# Cost at iteration 120 = 2.0256507202915395
#
# Cost at iteration 121 = 2.025102448421009
#
# Cost at iteration 122 = 2.024554351447737
#
# Cost at iteration 123 = 2.024006429315876
#
# Cost at iteration 124 = 2.023458681969597
#
# Cost at iteration 125 = 2.022911109353088
#
# Cost at iteration 126 = 2.022363711410556
#
# Cost at iteration 127 = 2.021816488086225
#
# Cost at iteration 128 = 2.0212694393243376
#
# Cost at iteration 129 = 2.0207225650691534
#
# Cost at iteration 130 = 2.0201758652649495
#
# Cost at iteration 131 = 2.019629339856022
#
# Cost at iteration 132 = 2.0190829887866846
#
# Cost at iteration 133 = 2.018536812001268
#
# Cost at iteration 134 = 2.0179908094441217
#
# Cost at iteration 135 = 2.0174449810596116
#
# Cost at iteration 136 = 2.016899326792122
#
# Cost at iteration 137 = 2.016353846586055
#
# Cost at iteration 138 = 2.015808540385833
#
# Cost at iteration 139 = 2.015263408135891
#
# Cost at iteration 140 = 2.0147184497806867
#
# Cost at iteration 141 = 2.0141736652646918
#
# Cost at iteration 142 = 2.013629054532397
#
# Cost at iteration 143 = 2.0130846175283135
#
# Cost at iteration 144 = 2.0125403541969655
#
# Cost at iteration 145 = 2.011996264482899
#
# Cost at iteration 146 = 2.0114523483306743
#
# Cost at iteration 147 = 2.0109086056848717
#
# Cost at iteration 148 = 2.010365036490089
#
# Cost at iteration 149 = 2.0098216406909417
#
# Cost at iteration 150 = 2.009278418232062
#
# Cost at iteration 151 = 2.0087353690581007
#
# Cost at iteration 152 = 2.0081924931137256
#
# Cost at iteration 153 = 2.0076497903436223
#
# Cost at iteration 154 = 2.007107260692495
#
# Cost at iteration 155 = 2.006564904105065
#
# Cost at iteration 156 = 2.0060227205260714
#
# Cost at iteration 157 = 2.0054807099002705
#
# Cost at iteration 158 = 2.0049388721724357
#
# Cost at iteration 159 = 2.0043972072873606
#
# Cost at iteration 160 = 2.0038557151898537
#
# Cost at iteration 161 = 2.0033143958247415
#
# Cost at iteration 162 = 2.00277324913687
#
# Cost at iteration 163 = 2.0022322750711012
#
# Cost at iteration 164 = 2.001691473572315
#
# Cost at iteration 165 = 2.0011508445854087
#
# Cost at iteration 166 = 2.000610388055299
#
# Cost at iteration 167 = 2.0000701039269164
#
# Cost at iteration 168 = 1.999529992145214
#
# Cost at iteration 169 = 1.9989900526551576
#
# Cost at iteration 170 = 1.9984502854017343
#
# Cost at iteration 171 = 1.997910690329947
#
# Cost at iteration 172 = 1.9973712673848172
#
# Cost at iteration 173 = 1.996832016511382
#
# Cost at iteration 174 = 1.9962929376546972
#
# Cost at iteration 175 = 1.995754030759838
#
# Cost at iteration 176 = 1.9952152957718943
#
# Cost at iteration 177 = 1.9946767326359744
#
# Cost at iteration 178 = 1.9941383412972045
#
# Cost at iteration 179 = 1.9936001217007302
#
# Cost at iteration 180 = 1.9930620737917104
#
# Cost at iteration 181 = 1.9925241975153247
#
# Cost at iteration 182 = 1.99198649281677
#
# Cost at iteration 183 = 1.9914489596412586
#
# Cost at iteration 184 = 1.9909115979340233
#
# Cost at iteration 185 = 1.9903744076403125
#
# Cost at iteration 186 = 1.9898373887053917
#
# Cost at iteration 187 = 1.9893005410745455
#
# Cost at iteration 188 = 1.9887638646930748
#
# Cost at iteration 189 = 1.988227359506299
#
# Cost at iteration 190 = 1.987691025459553
#
# Cost at iteration 191 = 1.9871548624981923
#
# Cost at iteration 192 = 1.9866188705675867
#
# Cost at iteration 193 = 1.9860830496131259
#
# Cost at iteration 194 = 1.9855473995802144
#
# Cost at iteration 195 = 1.9850119204142773
#
# Cost at iteration 196 = 1.9844766120607542
#
# Cost at iteration 197 = 1.9839414744651052
#
# Cost at iteration 198 = 1.9834065075728042
#
# Cost at iteration 199 = 1.9828717113293466
#
# Cost at iteration 200 = 1.9823370856802411
#
# Cost at iteration 201 = 1.9818026305710168
#
# Cost at iteration 202 = 1.9812683459472191
#
# Cost at iteration 203 = 1.9807342317544112
#
# Cost at iteration 204 = 1.9802002879381722
#
# Cost at iteration 205 = 1.979666514444101
#
# Cost at iteration 206 = 1.9791329112178129
#
# Cost at iteration 207 = 1.9785994782049396
#
# Cost at iteration 208 = 1.9780662153511313
#
# Cost at iteration 209 = 1.977533122602055
#
# Cost at iteration 210 = 1.977000199903395
#
# Cost at iteration 211 = 1.976467447200854
#
# Cost at iteration 212 = 1.9759348644401504
#
# Cost at iteration 213 = 1.975402451567022
#
# Cost at iteration 214 = 1.974870208527222
#
# Cost at iteration 215 = 1.974338135266521
#
# Cost at iteration 216 = 1.9738062317307088
#
# Cost at iteration 217 = 1.9732744978655916
#
# Cost at iteration 218 = 1.9727429336169917
#
# Cost at iteration 219 = 1.9722115389307495
#
# Cost at iteration 220 = 1.9716803137527241
#
# Cost at iteration 221 = 1.9711492580287906
#
# Cost at iteration 222 = 1.97061837170484
#
# Cost at iteration 223 = 1.9700876547267843
#
# Cost at iteration 224 = 1.9695571070405484
#
# Cost at iteration 225 = 1.9690267285920782
#
# Cost at iteration 226 = 1.968496519327335
#
# Cost at iteration 227 = 1.9679664791922973
#
# Cost at iteration 228 = 1.9674366081329617
#
# Cost at iteration 229 = 1.9669069060953412
#
# Cost at iteration 230 = 1.9663773730254668
#
# Cost at iteration 231 = 1.9658480088693864
#
# Cost at iteration 232 = 1.9653188135731652
#
# Cost at iteration 233 = 1.964789787082886
#
# Cost at iteration 234 = 1.964260929344648
#
# Cost at iteration 235 = 1.9637322403045678
#
# Cost at iteration 236 = 1.9632037199087795
#
# Cost at iteration 237 = 1.9626753681034357
#
# Cost at iteration 238 = 1.9621471848347034
#
# Cost at iteration 239 = 1.961619170048769
#
# Cost at iteration 240 = 1.9610913236918348
#
# Cost at iteration 241 = 1.9605636457101228
#
# Cost at iteration 242 = 1.9600361360498673
#
# Cost at iteration 243 = 1.9595087946573253
#
# Cost at iteration 244 = 1.958981621478767
#
# Cost at iteration 245 = 1.9584546164604821
#
# Cost at iteration 246 = 1.9579277795487766
#
# Cost at iteration 247 = 1.9574011106899727
#
# Cost at iteration 248 = 1.9568746098304113
#
# Cost at iteration 249 = 1.9563482769164504
#
# Cost at iteration 250 = 1.9558221118944639
#
# Cost at iteration 251 = 1.9552961147108436
#
# Cost at iteration 252 = 1.9547702853119988
#
# Cost at iteration 253 = 1.954244623644355
#
# Cost at iteration 254 = 1.9537191296543555
#
# Cost at iteration 255 = 1.9531938032884604
#
# Cost at iteration 256 = 1.9526686444931471
#
# Cost at iteration 257 = 1.9521436532149106
#
# Cost at iteration 258 = 1.9516188294002612
#
# Cost at iteration 259 = 1.951094172995729
#
# Cost at iteration 260 = 1.950569683947858
#
# Cost at iteration 261 = 1.9500453622032137
#
# Cost at iteration 262 = 1.9495212077083723
#
# Cost at iteration 263 = 1.9489972204099342
#
# Cost at iteration 264 = 1.948473400254512
#
# Cost at iteration 265 = 1.9479497471887357
#
# Cost at iteration 266 = 1.9474262611592557
#
# Cost at iteration 267 = 1.9469029421127357
#
# Cost at iteration 268 = 1.946379789995858
#
# Cost at iteration 269 = 1.9458568047553222
#
# Cost at iteration 270 = 1.9453339863378443
#
# Cost at iteration 271 = 1.9448113346901574
#
# Cost at iteration 272 = 1.944288849759014
#
# Cost at iteration 273 = 1.943766531491179
#
# Cost at iteration 274 = 1.9432443798334373
#
# Cost at iteration 275 = 1.9427223947325905
#
# Cost at iteration 276 = 1.9422005761354575
#
# Cost at iteration 277 = 1.941678923988873
#
# Cost at iteration 278 = 1.9411574382396894
#
# Cost at iteration 279 = 1.9406361188347765
#
# Cost at iteration 280 = 1.9401149657210208
#
# Cost at iteration 281 = 1.9395939788453251
#
# Cost at iteration 282 = 1.9390731581546097
#
# Cost at iteration 283 = 1.9385525035958127
#
# Cost at iteration 284 = 1.938032015115887
#
# Cost at iteration 285 = 1.9375116926618041
#
# Cost at iteration 286 = 1.9369915361805528
#
# Cost at iteration 287 = 1.936471545619138
#
# Cost at iteration 288 = 1.935951720924581
#
# Cost at iteration 289 = 1.9354320620439212
#
# Cost at iteration 290 = 1.934912568924214
#
# Cost at iteration 291 = 1.9343932415125331
#
# Cost at iteration 292 = 1.9338740797559677
#
# Cost at iteration 293 = 1.9333550836016236
#
# Cost at iteration 294 = 1.9328362529966256
#
# Cost at iteration 295 = 1.9323175878881134
#
# Cost at iteration 296 = 1.9317990882232439
#
# Cost at iteration 297 = 1.9312807539491919
#
# Cost at iteration 298 = 1.9307625850131478
#
# Cost at iteration 299 = 1.9302445813623208
#
# Cost at iteration 300 = 1.9297267429439342
#
# Cost at iteration 301 = 1.9292090697052307
#
# Cost at iteration 302 = 1.928691561593468
#
# Cost at iteration 303 = 1.9281742185559223
#
# Cost at iteration 304 = 1.9276570405398845
#
# Cost at iteration 305 = 1.9271400274926658
#
# Cost at iteration 306 = 1.9266231793615896
#
# Cost at iteration 307 = 1.9261064960940002
#
# Cost at iteration 308 = 1.9255899776372574
#
# Cost at iteration 309 = 1.9250736239387363
#
# Cost at iteration 310 = 1.9245574349458314
#
# Cost at iteration 311 = 1.9240414106059511
#
# Cost at iteration 312 = 1.9235255508665248
#
# Cost at iteration 313 = 1.9230098556749935
#
# Cost at iteration 314 = 1.922494324978819
#
# Cost at iteration 315 = 1.921978958725478
#
# Cost at iteration 316 = 1.9214637568624648
#
# Cost at iteration 317 = 1.9209487193372896
#
# Cost at iteration 318 = 1.9204338460974812
#
# Cost at iteration 319 = 1.9199191370905824
#
# Cost at iteration 320 = 1.9194045922641554
#
# Cost at iteration 321 = 1.918890211565777
#
# Cost at iteration 322 = 1.918375994943043
#
# Cost at iteration 323 = 1.9178619423435637
#
# Cost at iteration 324 = 1.9173480537149679
#
# Cost at iteration 325 = 1.9168343290048995
#
# Cost at iteration 326 = 1.9163207681610213
#
# Cost at iteration 327 = 1.9158073711310106
#
# Cost at iteration 328 = 1.9152941378625628
#
# Cost at iteration 329 = 1.914781068303389
#
# Cost at iteration 330 = 1.9142681624012186
#
# Cost at iteration 331 = 1.9137554201037958
#
# Cost at iteration 332 = 1.9132428413588827
#
# Cost at iteration 333 = 1.9127304261142584
#
# Cost at iteration 334 = 1.9122181743177176
#
# Cost at iteration 335 = 1.9117060859170716
#
# Cost at iteration 336 = 1.91119416086015
#
# Cost at iteration 337 = 1.9106823990947976
#
# Cost at iteration 338 = 1.9101708005688756
#
# Cost at iteration 339 = 1.9096593652302638
#
# Cost at iteration 340 = 1.909148093026856
#
# Cost at iteration 341 = 1.908636983906566
#
# Cost at iteration 342 = 1.9081260378173206
#
# Cost at iteration 343 = 1.9076152547070653
#
# Cost at iteration 344 = 1.907104634523762
#
# Cost at iteration 345 = 1.9065941772153903
#
# Cost at iteration 346 = 1.9060838827299427
#
# Cost at iteration 347 = 1.905573751015433
#
# Cost at iteration 348 = 1.9050637820198888
#
# Cost at iteration 349 = 1.9045539756913554
#
# Cost at iteration 350 = 1.904044331977893
#
# Cost at iteration 351 = 1.9035348508275813
#
# Cost at iteration 352 = 1.9030255321885137
#
# Cost at iteration 353 = 1.9025163760088017
#
# Cost at iteration 354 = 1.9020073822365728
#
# Cost at iteration 355 = 1.9014985508199733
#
# Cost at iteration 356 = 1.9009898817071624
#
# Cost at iteration 357 = 1.9004813748463179
#
# Cost at iteration 358 = 1.899973030185634
#
# Cost at iteration 359 = 1.8994648476733218
#
# Cost at iteration 360 = 1.898956827257608
#
# Cost at iteration 361 = 1.8984489688867359
#
# Cost at iteration 362 = 1.8979412725089682
#
# Cost at iteration 363 = 1.8974337380725788
#
# Cost at iteration 364 = 1.8969263655258621
#
# Cost at iteration 365 = 1.8964191548171285
#
# Cost at iteration 366 = 1.895912105894704
#
# Cost at iteration 367 = 1.895405218706931
#
# Cost at iteration 368 = 1.8948984932021706
#
# Cost at iteration 369 = 1.8943919293287967
#
# Cost at iteration 370 = 1.8938855270352033
#
# Cost at iteration 371 = 1.8933792862697982
#
# Cost at iteration 372 = 1.8928732069810068
#
# Cost at iteration 373 = 1.8923672891172725
#
# Cost at iteration 374 = 1.8918615326270523
#
# Cost at iteration 375 = 1.8913559374588211
#
# Cost at iteration 376 = 1.8908505035610697
#
# Cost at iteration 377 = 1.8903452308823077
#
# Cost at iteration 378 = 1.8898401193710574
#
# Cost at iteration 379 = 1.8893351689758608
#
# Cost at iteration 380 = 1.888830379645274
#
# Cost at iteration 381 = 1.8883257513278717
#
# Cost at iteration 382 = 1.887821283972242
#
# Cost at iteration 383 = 1.8873169775269931
#
# Cost at iteration 384 = 1.8868128319407471
#
# Cost at iteration 385 = 1.8863088471621436
#
# Cost at iteration 386 = 1.8858050231398376
#
# Cost at iteration 387 = 1.885301359822501
#
# Cost at iteration 388 = 1.8847978571588235
#
# Cost at iteration 389 = 1.8842945150975092
#
# Cost at iteration 390 = 1.88379133358728
#
# Cost at iteration 391 = 1.883288312576872
#
# Cost at iteration 392 = 1.8827854520150409
#
# Cost at iteration 393 = 1.882282751850556
#
# Cost at iteration 394 = 1.8817802120322042
#
# Cost at iteration 395 = 1.8812778325087898
#
# Cost at iteration 396 = 1.8807756132291307
#
# Cost at iteration 397 = 1.8802735541420632
#
# Cost at iteration 398 = 1.87977165519644
#
# Cost at iteration 399 = 1.87926991634113
#
# Cost at iteration 400 = 1.878768337525017
#
# Cost at iteration 401 = 1.8782669186970025
#
# Cost at iteration 402 = 1.8777656598060046
#
# Cost at iteration 403 = 1.8772645608009568
#
# Cost at iteration 404 = 1.876763621630809
#
# Cost at iteration 405 = 1.8762628422445282
#
# Cost at iteration 406 = 1.875762222591097
#
# Cost at iteration 407 = 1.8752617626195138
#
# Cost at iteration 408 = 1.8747614622787965
#
# Cost at iteration 409 = 1.874261321517974
#
# Cost at iteration 410 = 1.8737613402860946
#
# Cost at iteration 411 = 1.8732615185322243
#
# Cost at iteration 412 = 1.8727618562054424
#
# Cost at iteration 413 = 1.872262353254846
#
# Cost at iteration 414 = 1.8717630096295483
#
# Cost at iteration 415 = 1.8712638252786782
#
# Cost at iteration 416 = 1.8707648001513817
#
# Cost at iteration 417 = 1.8702659341968204
#
# Cost at iteration 418 = 1.869767227364173
#
# Cost at iteration 419 = 1.8692686796026328
#
# Cost at iteration 420 = 1.8687702908614114
#
# Cost at iteration 421 = 1.8682720610897348
#
# Cost at iteration 422 = 1.8677739902368466
#
# Cost at iteration 423 = 1.8672760782520064
#
# Cost at iteration 424 = 1.8667783250844883
#
# Cost at iteration 425 = 1.8662807306835856
#
# Cost at iteration 426 = 1.8657832949986048
#
# Cost at iteration 427 = 1.8652860179788706
#
# Cost at iteration 428 = 1.8647888995737232
#
# Cost at iteration 429 = 1.8642919397325195
#
# Cost at iteration 430 = 1.8637951384046314
#
# Cost at iteration 431 = 1.8632984955394483
#
# Cost at iteration 432 = 1.8628020110863748
#
# Cost at iteration 433 = 1.8623056849948318
#
# Cost at iteration 434 = 1.8618095172142572
#
# Cost at iteration 435 = 1.8613135076941045
#
# Cost at iteration 436 = 1.8608176563838432
#
# Cost at iteration 437 = 1.8603219632329584
#
# Cost at iteration 438 = 1.8598264281909531
#
# Cost at iteration 439 = 1.8593310512073444
#
# Cost at iteration 440 = 1.8588358322316676
#
# Cost at iteration 441 = 1.858340771213472
#
# Cost at iteration 442 = 1.8578458681023247
#
# Cost at iteration 443 = 1.8573511228478075
#
# Cost at iteration 444 = 1.85685653539952
#
# Cost at iteration 445 = 1.856362105707076
#
# Cost at iteration 446 = 1.8558678337201073
#
# Cost at iteration 447 = 1.85537371938826
#
# Cost at iteration 448 = 1.8548797626611981
#
# Cost at iteration 449 = 1.8543859634886
#
# Cost at iteration 450 = 1.8538923218201613
#
# Cost at iteration 451 = 1.8533988376055925
#
# Cost at iteration 452 = 1.852905510794622
#
# Cost at iteration 453 = 1.8524123413369926
#
# Cost at iteration 454 = 1.8519193291824643
#
# Cost at iteration 455 = 1.8514264742808124
#
# Cost at iteration 456 = 1.8509337765818283
#
# Cost at iteration 457 = 1.8504412360353195
#
# Cost at iteration 458 = 1.8499488525911105
#
# Cost at iteration 459 = 1.8494566261990397
#
# Cost at iteration 460 = 1.8489645568089643
#
# Cost at iteration 461 = 1.8484726443707546
#
# Cost at iteration 462 = 1.8479808888342997
#
# Cost at iteration 463 = 1.8474892901495028
#
# Cost at iteration 464 = 1.8469978482662839
#
# Cost at iteration 465 = 1.846506563134579
#
# Cost at iteration 466 = 1.846015434704338
#
# Cost at iteration 467 = 1.8455244629255316
#
# Cost at iteration 468 = 1.8450336477481413
#
# Cost at iteration 469 = 1.8445429891221683
#
# Cost at iteration 470 = 1.8440524869976285
#
# Cost at iteration 471 = 1.843562141324551
#
# Cost at iteration 472 = 1.8430719520529875
#
# Cost at iteration 473 = 1.842581919132998
#
# Cost at iteration 474 = 1.8420920425146643
#
# Cost at iteration 475 = 1.841602322148081
#
# Cost at iteration 476 = 1.8411127579833602
#
# Cost at iteration 477 = 1.840623349970629
#
# Cost at iteration 478 = 1.8401340980600305
#
# Cost at iteration 479 = 1.8396450022017246
#
# Cost at iteration 480 = 1.8391560623458858
#
# Cost at iteration 481 = 1.8386672784427058
#
# Cost at iteration 482 = 1.8381786504423916
#
# Cost at iteration 483 = 1.8376901782951671
#
# Cost at iteration 484 = 1.837201861951269
#
# Cost at iteration 485 = 1.8367137013609542
#
# Cost at iteration 486 = 1.8362256964744916
#
# Cost at iteration 487 = 1.8357378472421693
#
# Cost at iteration 488 = 1.8352501536142884
#
# Cost at iteration 489 = 1.8347626155411687
#
# Cost at iteration 490 = 1.834275232973144
#
# Cost at iteration 491 = 1.8337880058605636
#
# Cost at iteration 492 = 1.833300934153794
#
# Cost at iteration 493 = 1.8328140178032173
#
# Cost at iteration 494 = 1.8323272567592301
#
# Cost at iteration 495 = 1.8318406509722476
#
# Cost at iteration 496 = 1.8313542003926973
#
# Cost at iteration 497 = 1.830867904971026
#
# Cost at iteration 498 = 1.8303817646576934
#
# Cost at iteration 499 = 1.8298957794031772
#
# Cost at iteration 500 = 1.82940994915797
#
# Cost at iteration 501 = 1.8289242738725808
#
# Cost at iteration 502 = 1.8284387534975326
#
# Cost at iteration 503 = 1.8279533879833667
#
# Cost at iteration 504 = 1.827468177280638
#
# Cost at iteration 505 = 1.8269831213399192
#
# Cost at iteration 506 = 1.8264982201117976
#
# Cost at iteration 507 = 1.826013473546877
#
# Cost at iteration 508 = 1.825528881595775
#
# Cost at iteration 509 = 1.8250444442091276
#
# Cost at iteration 510 = 1.8245601613375855
#
# Cost at iteration 511 = 1.8240760329318146
#
# Cost at iteration 512 = 1.8235920589424979
#
# Cost at iteration 513 = 1.823108239320333
#
# Cost at iteration 514 = 1.8226245740160334
#
# Cost at iteration 515 = 1.8221410629803283
#
# Cost at iteration 516 = 1.8216577061639632
#
# Cost at iteration 517 = 1.8211745035176987
#
# Cost at iteration 518 = 1.8206914549923132
#
# Cost at iteration 519 = 1.8202085605385974
#
# Cost at iteration 520 = 1.8197258201073587
#
# Cost at iteration 521 = 1.8192432336494226
#
# Cost at iteration 522 = 1.8187608011156282
#
# Cost at iteration 523 = 1.8182785224568303
#
# Cost at iteration 524 = 1.817796397623901
#
# Cost at iteration 525 = 1.8173144265677261
#
# Cost at iteration 526 = 1.816832609239207
#
# Cost at iteration 527 = 1.816350945589264
#
# Cost at iteration 528 = 1.8158694355688294
#
# Cost at iteration 529 = 1.815388079128853
#
# Cost at iteration 530 = 1.8149068762202991
#
# Cost at iteration 531 = 1.8144258267941498
#
# Cost at iteration 532 = 1.8139449308014004
#
# Cost at iteration 533 = 1.8134641881930635
#
# Cost at iteration 534 = 1.8129835989201664
#
# Cost at iteration 535 = 1.8125031629337538
#
# Cost at iteration 536 = 1.8120228801848839
#
# Cost at iteration 537 = 1.8115427506246298
#
# Cost at iteration 538 = 1.811062774204084
#
# Cost at iteration 539 = 1.8105829508743516
#
# Cost at iteration 540 = 1.8101032805865545
#
# Cost at iteration 541 = 1.8096237632918295
#
# Cost at iteration 542 = 1.8091443989413298
#
# Cost at iteration 543 = 1.8086651874862227
#
# Cost at iteration 544 = 1.8081861288776935
#
# Cost at iteration 545 = 1.8077072230669406
#
# Cost at iteration 546 = 1.8072284700051806
#
# Cost at iteration 547 = 1.806749869643643
#
# Cost at iteration 548 = 1.8062714219335747
#
# Cost at iteration 549 = 1.8057931268262377
#
# Cost at iteration 550 = 1.805314984272909
#
# Cost at iteration 551 = 1.804836994224883
#
# Cost at iteration 552 = 1.804359156633467
#
# Cost at iteration 553 = 1.8038814714499853
#
# Cost at iteration 554 = 1.8034039386257783
#
# Cost at iteration 555 = 1.802926558112201
#
# Cost at iteration 556 = 1.8024493298606246
#
# Cost at iteration 557 = 1.8019722538224343
#
# Cost at iteration 558 = 1.8014953299490337
#
# Cost at iteration 559 = 1.8010185581918383
#
# Cost at iteration 560 = 1.8005419385022838
#
# Cost at iteration 561 = 1.8000654708318158
#
# Cost at iteration 562 = 1.7995891551319
#
# Cost at iteration 563 = 1.799112991354015
#
# Cost at iteration 564 = 1.7986369794496568
#
# Cost at iteration 565 = 1.798161119370336
#
# Cost at iteration 566 = 1.7976854110675775
#
# Cost at iteration 567 = 1.7972098544929231
#
# Cost at iteration 568 = 1.79673444959793
#
# Cost at iteration 569 = 1.796259196334171
#
# Cost at iteration 570 = 1.7957840946532344
#
# Cost at iteration 571 = 1.7953091445067215
#
# Cost at iteration 572 = 1.7948343458462541
#
# Cost at iteration 573 = 1.7943596986234642
#
# Cost at iteration 574 = 1.7938852027900032
#
# Cost at iteration 575 = 1.7934108582975348
#
# Cost at iteration 576 = 1.79293666509774
#
# Cost at iteration 577 = 1.7924626231423169
#
# Cost at iteration 578 = 1.7919887323829746
#
# Cost at iteration 579 = 1.791514992771441
#
# Cost at iteration 580 = 1.791041404259459
#
# Cost at iteration 581 = 1.7905679667987857
#
# Cost at iteration 582 = 1.7900946803411952
#
# Cost at iteration 583 = 1.7896215448384747
#
# Cost at iteration 584 = 1.7891485602424293
#
# Cost at iteration 585 = 1.7886757265048787
#
# Cost at iteration 586 = 1.7882030435776572
#
# Cost at iteration 587 = 1.7877305114126156
#
# Cost at iteration 588 = 1.7872581299616193
#
# Cost at iteration 589 = 1.7867858991765484
#
# Cost at iteration 590 = 1.7863138190093002
#
# Cost at iteration 591 = 1.7858418894117867
#
# Cost at iteration 592 = 1.7853701103359343
#
# Cost at iteration 593 = 1.7848984817336861
#
# Cost at iteration 594 = 1.784427003557
#
# Cost at iteration 595 = 1.7839556757578483
#
# Cost at iteration 596 = 1.7834844982882208
#
# Cost at iteration 597 = 1.7830134711001202
#
# Cost at iteration 598 = 1.7825425941455662
#
# Cost at iteration 599 = 1.7820718673765936
#
# Cost at iteration 600 = 1.7816012907452523
#
# Cost at iteration 601 = 1.7811308642036063
#
# Cost at iteration 602 = 1.780660587703738
#
# Cost at iteration 603 = 1.7801904611977417
#
# Cost at iteration 604 = 1.779720484637729
#
# Cost at iteration 605 = 1.779250657975827
#
# Cost at iteration 606 = 1.7787809811641766
#
# Cost at iteration 607 = 1.7783114541549359
#
# Cost at iteration 608 = 1.7778420769002752
#
# Cost at iteration 609 = 1.777372849352384
#
# Cost at iteration 610 = 1.7769037714634641
#
# Cost at iteration 611 = 1.7764348431857353
#
# Cost at iteration 612 = 1.7759660644714288
#
# Cost at iteration 613 = 1.775497435272794
#
# Cost at iteration 614 = 1.775028955542096
#
# Cost at iteration 615 = 1.7745606252316117
#
# Cost at iteration 616 = 1.7740924442936377
#
# Cost at iteration 617 = 1.7736244126804832
#
# Cost at iteration 618 = 1.7731565303444725
#
# Cost at iteration 619 = 1.7726887972379457
#
# Cost at iteration 620 = 1.7722212133132593
#
# Cost at iteration 621 = 1.7717537785227826
#
# Cost at iteration 622 = 1.771286492818902
#
# Cost at iteration 623 = 1.7708193561540186
#
# Cost at iteration 624 = 1.7703523684805487
#
# Cost at iteration 625 = 1.7698855297509237
#
# Cost at iteration 626 = 1.76941883991759
#
# Cost at iteration 627 = 1.7689522989330093
#
# Cost at iteration 628 = 1.7684859067496588
#
# Cost at iteration 629 = 1.7680196633200316
#
# Cost at iteration 630 = 1.7675535685966344
#
# Cost at iteration 631 = 1.767087622531989
#
# Cost at iteration 632 = 1.7666218250786343
#
# Cost at iteration 633 = 1.7661561761891227
#
# Cost at iteration 634 = 1.7656906758160227
#
# Cost at iteration 635 = 1.7652253239119164
#
# Cost at iteration 636 = 1.7647601204294034
#
# Cost at iteration 637 = 1.764295065321098
#
# Cost at iteration 638 = 1.7638301585396263
#
# Cost at iteration 639 = 1.7633654000376344
#
# Cost at iteration 640 = 1.762900789767779
#
# Cost at iteration 641 = 1.7624363276827368
#
# Cost at iteration 642 = 1.761972013735195
#
# Cost at iteration 643 = 1.7615078478778585
#
# Cost at iteration 644 = 1.7610438300634477
#
# Cost at iteration 645 = 1.7605799602446957
#
# Cost at iteration 646 = 1.760116238374352
#
# Cost at iteration 647 = 1.759652664405183
#
# Cost at iteration 648 = 1.7591892382899672
#
# Cost at iteration 649 = 1.7587259599814995
#
# Cost at iteration 650 = 1.7582628294325906
#
# Cost at iteration 651 = 1.7577998465960647
#
# Cost at iteration 652 = 1.7573370114247626
#
# Cost at iteration 653 = 1.75687432387154
#
# Cost at iteration 654 = 1.7564117838892657
#
# Cost at iteration 655 = 1.7559493914308255
#
# Cost at iteration 656 = 1.755487146449121
#
# Cost at iteration 657 = 1.7550250488970662
#
# Cost at iteration 658 = 1.7545630987275924
#
# Cost at iteration 659 = 1.754101295893645
#
# Cost at iteration 660 = 1.7536396403481842
#
# Cost at iteration 661 = 1.7531781320441857
#
# Cost at iteration 662 = 1.7527167709346403
#
# Cost at iteration 663 = 1.7522555569725538
#
# Cost at iteration 664 = 1.751794490110946
#
# Cost at iteration 665 = 1.7513335703028532
#
# Cost at iteration 666 = 1.750872797501327
#
# Cost at iteration 667 = 1.7504121716594307
#
# Cost at iteration 668 = 1.7499516927302476
#
# Cost at iteration 669 = 1.7494913606668714
#
# Cost at iteration 670 = 1.7490311754224144
#
# Cost at iteration 671 = 1.7485711369500003
#
# Cost at iteration 672 = 1.7481112452027712
#
# Cost at iteration 673 = 1.7476515001338817
#
# Cost at iteration 674 = 1.7471919016965036
#
# Cost at iteration 675 = 1.7467324498438213
#
# Cost at iteration 676 = 1.7462731445290358
#
# Cost at iteration 677 = 1.7458139857053623
#
# Cost at iteration 678 = 1.7453549733260312
#
# Cost at iteration 679 = 1.7448961073442875
#
# Cost at iteration 680 = 1.7444373877133919
#
# Cost at iteration 681 = 1.7439788143866202
#
# Cost at iteration 682 = 1.7435203873172604
#
# Cost at iteration 683 = 1.7430621064586203
#
# Cost at iteration 684 = 1.7426039717640183
#
# Cost at iteration 685 = 1.7421459831867894
#
# Cost at iteration 686 = 1.7416881406802835
#
# Cost at iteration 687 = 1.741230444197865
#
# Cost at iteration 688 = 1.7407728936929139
#
# Cost at iteration 689 = 1.7403154891188246
#
# Cost at iteration 690 = 1.7398582304290064
#
# Cost at iteration 691 = 1.7394011175768838
#
# Cost at iteration 692 = 1.7389441505158958
#
# Cost at iteration 693 = 1.738487329199496
#
# Cost at iteration 694 = 1.7380306535811547
#
# Cost at iteration 695 = 1.7375741236143545
#
# Cost at iteration 696 = 1.7371177392525938
#
# Cost at iteration 697 = 1.7366615004493868
#
# Cost at iteration 698 = 1.736205407158262
#
# Cost at iteration 699 = 1.7357494593327616
#
# Cost at iteration 700 = 1.7352936569264445
#
# Cost at iteration 701 = 1.7348379998928836
#
# Cost at iteration 702 = 1.7343824881856658
#
# Cost at iteration 703 = 1.7339271217583947
#
# Cost at iteration 704 = 1.7334719005646866
#
# Cost at iteration 705 = 1.733016824558175
#
# Cost at iteration 706 = 1.7325618936925056
#
# Cost at iteration 707 = 1.732107107921341
#
# Cost at iteration 708 = 1.7316524671983573
#
# Cost at iteration 709 = 1.7311979714772467
#
# Cost at iteration 710 = 1.730743620711715
#
# Cost at iteration 711 = 1.7302894148554837
#
# Cost at iteration 712 = 1.7298353538622873
#
# Cost at iteration 713 = 1.7293814376858776
#
# Cost at iteration 714 = 1.7289276662800193
#
# Cost at iteration 715 = 1.7284740395984928
#
# Cost at iteration 716 = 1.7280205575950927
#
# Cost at iteration 717 = 1.7275672202236296
#
# Cost at iteration 718 = 1.7271140274379269
#
# Cost at iteration 719 = 1.726660979191824
#
# Cost at iteration 720 = 1.7262080754391758
#
# Cost at iteration 721 = 1.7257553161338497
#
# Cost at iteration 722 = 1.7253027012297293
#
# Cost at iteration 723 = 1.7248502306807136
#
# Cost at iteration 724 = 1.7243979044407145
#
# Cost at iteration 725 = 1.72394572246366
#
# Cost at iteration 726 = 1.723493684703493
#
# Cost at iteration 727 = 1.7230417911141696
#
# Cost at iteration 728 = 1.7225900416496625
#
# Cost at iteration 729 = 1.7221384362639571
#
# Cost at iteration 730 = 1.721686974911055
#
# Cost at iteration 731 = 1.7212356575449728
#
# Cost at iteration 732 = 1.7207844841197404
#
# Cost at iteration 733 = 1.7203334545894025
#
# Cost at iteration 734 = 1.7198825689080204
#
# Cost at iteration 735 = 1.7194318270296673
#
# Cost at iteration 736 = 1.7189812289084332
#
# Cost at iteration 737 = 1.7185307744984222
#
# Cost at iteration 738 = 1.718080463753753
#
# Cost at iteration 739 = 1.7176302966285573
#
# Cost at iteration 740 = 1.7171802730769856
#
# Cost at iteration 741 = 1.716730393053199
#
# Cost at iteration 742 = 1.7162806565113746
#
# Cost at iteration 743 = 1.7158310634057046
#
# Cost at iteration 744 = 1.715381613690396
#
# Cost at iteration 745 = 1.714932307319669
#
# Cost at iteration 746 = 1.7144831442477597
#
# Cost at iteration 747 = 1.7140341244289188
#
# Cost at iteration 748 = 1.713585247817411
#
# Cost at iteration 749 = 1.7131365143675166
#
# Cost at iteration 750 = 1.7126879240335287
#
# Cost at iteration 751 = 1.712239476769757
#
# Cost at iteration 752 = 1.7117911725305244
#
# Cost at iteration 753 = 1.7113430112701693
#
# Cost at iteration 754 = 1.710894992943044
#
# Cost at iteration 755 = 1.710447117503516
#
# Cost at iteration 756 = 1.7099993849059674
#
# Cost at iteration 757 = 1.7095517951047938
#
# Cost at iteration 758 = 1.7091043480544068
#
# Cost at iteration 759 = 1.7086570437092317
#
# Cost at iteration 760 = 1.708209882023708
#
# Cost at iteration 761 = 1.7077628629522903
#
# Cost at iteration 762 = 1.7073159864494496
#
# Cost at iteration 763 = 1.7068692524696674
#
# Cost at iteration 764 = 1.706422660967443
#
# Cost at iteration 765 = 1.7059762118972892
#
# Cost at iteration 766 = 1.705529905213733
#
# Cost at iteration 767 = 1.7050837408713164
#
# Cost at iteration 768 = 1.704637718824596
#
# Cost at iteration 769 = 1.7041918390281428
#
# Cost at iteration 770 = 1.7037461014365416
#
# Cost at iteration 771 = 1.7033005060043929
#
# Cost at iteration 772 = 1.7028550526863107
#
# Cost at iteration 773 = 1.7024097414369246
#
# Cost at iteration 774 = 1.7019645722108776
#
# Cost at iteration 775 = 1.701519544962827
#
# Cost at iteration 776 = 1.701074659647447
#
# Cost at iteration 777 = 1.700629916219423
#
# Cost at iteration 778 = 1.7001853146334567
#
# Cost at iteration 779 = 1.6997408548442643
#
# Cost at iteration 780 = 1.6992965368065756
#
# Cost at iteration 781 = 1.6988523604751362
#
# Cost at iteration 782 = 1.698408325804704
#
# Cost at iteration 783 = 1.6979644327500543
#
# Cost at iteration 784 = 1.6975206812659747
#
# Cost at iteration 785 = 1.6970770713072674
#
# Cost at iteration 786 = 1.6966336028287488
#
# Cost at iteration 787 = 1.6961902757852525
#
# Cost at iteration 788 = 1.695747090131622
#
# Cost at iteration 789 = 1.6953040458227202
#
# Cost at iteration 790 = 1.6948611428134195
#
# Cost at iteration 791 = 1.6944183810586102
#
# Cost at iteration 792 = 1.6939757605131964
#
# Cost at iteration 793 = 1.6935332811320947
#
# Cost at iteration 794 = 1.6930909428702388
#
# Cost at iteration 795 = 1.692648745682575
#
# Cost at iteration 796 = 1.6922066895240646
#
# Cost at iteration 797 = 1.6917647743496829
#
# Cost at iteration 798 = 1.6913230001144204
#
# Cost at iteration 799 = 1.6908813667732807
#
# Cost at iteration 800 = 1.6904398742812836
#
# Cost at iteration 801 = 1.6899985225934615
#
# Cost at iteration 802 = 1.6895573116648621
#
# Cost at iteration 803 = 1.689116241450547
#
# Cost at iteration 804 = 1.6886753119055926
#
# Cost at iteration 805 = 1.6882345229850895
#
# Cost at iteration 806 = 1.6877938746441423
#
# Cost at iteration 807 = 1.6873533668378708
#
# Cost at iteration 808 = 1.6869129995214085
#
# Cost at iteration 809 = 1.6864727726499031
#
# Cost at iteration 810 = 1.6860326861785162
#
# Cost at iteration 811 = 1.685592740062426
#
# Cost at iteration 812 = 1.6851529342568223
#
# Cost at iteration 813 = 1.6847132687169102
#
# Cost at iteration 814 = 1.6842737433979103
#
# Cost at iteration 815 = 1.6838343582550557
#
# Cost at iteration 816 = 1.6833951132435938
#
# Cost at iteration 817 = 1.682956008318788
#
# Cost at iteration 818 = 1.6825170434359156
#
# Cost at iteration 819 = 1.6820782185502663
#
# Cost at iteration 820 = 1.6816395336171464
#
# Cost at iteration 821 = 1.6812009885918753
#
# Cost at iteration 822 = 1.680762583429786
#
# Cost at iteration 823 = 1.6803243180862277
#
# Cost at iteration 824 = 1.6798861925165631
#
# Cost at iteration 825 = 1.6794482066761685
#
# Cost at iteration 826 = 1.6790103605204338
#
# Cost at iteration 827 = 1.6785726540047652
#
# Cost at iteration 828 = 1.6781350870845817
#
# Cost at iteration 829 = 1.6776976597153177
#
# Cost at iteration 830 = 1.677260371852421
#
# Cost at iteration 831 = 1.6768232234513532
#
# Cost at iteration 832 = 1.6763862144675907
#
# Cost at iteration 833 = 1.675949344856624
#
# Cost at iteration 834 = 1.6755126145739592
#
# Cost at iteration 835 = 1.6750760235751136
#
# Cost at iteration 836 = 1.6746395718156222
#
# Cost at iteration 837 = 1.6742032592510314
#
# Cost at iteration 838 = 1.6737670858369025
#
# Cost at iteration 839 = 1.673331051528813
#
# Cost at iteration 840 = 1.672895156282351
#
# Cost at iteration 841 = 1.6724594000531212
#
# Cost at iteration 842 = 1.672023782796744
#
# Cost at iteration 843 = 1.6715883044688498
#
# Cost at iteration 844 = 1.6711529650250863
#
# Cost at iteration 845 = 1.6707177644211144
#
# Cost at iteration 846 = 1.6702827026126095
#
# Cost at iteration 847 = 1.6698477795552602
#
# Cost at iteration 848 = 1.6694129952047705
#
# Cost at iteration 849 = 1.6689783495168584
#
# Cost at iteration 850 = 1.6685438424472547
#
# Cost at iteration 851 = 1.6681094739517057
#
# Cost at iteration 852 = 1.6676752439859717
#
# Cost at iteration 853 = 1.6672411525058266
#
# Cost at iteration 854 = 1.6668071994670592
#
# Cost at iteration 855 = 1.6663733848254716
#
# Cost at iteration 856 = 1.6659397085368801
#
# Cost at iteration 857 = 1.6655061705571157
#
# Cost at iteration 858 = 1.6650727708420232
#
# Cost at iteration 859 = 1.6646395093474617
#
# Cost at iteration 860 = 1.6642063860293037
#
# Cost at iteration 861 = 1.6637734008434368
#
# Cost at iteration 862 = 1.6633405537457617
#
# Cost at iteration 863 = 1.6629078446921945
#
# Cost at iteration 864 = 1.6624752736386634
#
# Cost at iteration 865 = 1.662042840541113
#
# Cost at iteration 866 = 1.6616105453555001
#
# Cost at iteration 867 = 1.6611783880377964
#
# Cost at iteration 868 = 1.6607463685439885
#
# Cost at iteration 869 = 1.6603144868300752
#
# Cost at iteration 870 = 1.6598827428520697
#
# Cost at iteration 871 = 1.6594511365660014
#
# Cost at iteration 872 = 1.6590196679279114
#
# Cost at iteration 873 = 1.6585883368938559
#
# Cost at iteration 874 = 1.6581571434199043
#
# Cost at iteration 875 = 1.6577260874621413
#
# Cost at iteration 876 = 1.6572951689766648
#
# Cost at iteration 877 = 1.6568643879195861
#
# Cost at iteration 878 = 1.656433744247033
#
# Cost at iteration 879 = 1.656003237915144
#
# Cost at iteration 880 = 1.655572868880074
#
# Cost at iteration 881 = 1.6551426370979911
#
# Cost at iteration 882 = 1.6547125425250773
#
# Cost at iteration 883 = 1.6542825851175287
#
# Cost at iteration 884 = 1.6538527648315557
#
# Cost at iteration 885 = 1.6534230816233826
#
# Cost at iteration 886 = 1.652993535449247
#
# Cost at iteration 887 = 1.6525641262654016
#
# Cost at iteration 888 = 1.6521348540281122
#
# Cost at iteration 889 = 1.6517057186936586
#
# Cost at iteration 890 = 1.6512767202183352
#
# Cost at iteration 891 = 1.6508478585584498
#
# Cost at iteration 892 = 1.650419133670325
#
# Cost at iteration 893 = 1.6499905455102954
#
# Cost at iteration 894 = 1.6495620940347127
#
# Cost at iteration 895 = 1.6491337791999385
#
# Cost at iteration 896 = 1.6487056009623526
#
# Cost at iteration 897 = 1.6482775592783456
#
# Cost at iteration 898 = 1.6478496541043233
#
# Cost at iteration 899 = 1.647421885396705
#
# Cost at iteration 900 = 1.646994253111925
#
# Cost at iteration 901 = 1.64656675720643
#
# Cost at iteration 902 = 1.6461393976366814
#
# Cost at iteration 903 = 1.6457121743591554
#
# Cost at iteration 904 = 1.6452850873303395
#
# Cost at iteration 905 = 1.6448581365067374
#
# Cost at iteration 906 = 1.6444313218448667
#
# Cost at iteration 907 = 1.6440046433012576
#
# Cost at iteration 908 = 1.6435781008324546
#
# Cost at iteration 909 = 1.6431516943950173
#
# Cost at iteration 910 = 1.6427254239455171
#
# Cost at iteration 911 = 1.6422992894405408
#
# Cost at iteration 912 = 1.6418732908366889
#
# Cost at iteration 913 = 1.6414474280905755
#
# Cost at iteration 914 = 1.641021701158828
#
# Cost at iteration 915 = 1.6405961099980881
#
# Cost at iteration 916 = 1.6401706545650123
#
# Cost at iteration 917 = 1.6397453348162696
#
# Cost at iteration 918 = 1.6393201507085438
#
# Cost at iteration 919 = 1.6388951021985316
#
# Cost at iteration 920 = 1.6384701892429445
#
# Cost at iteration 921 = 1.6380454117985068
#
# Cost at iteration 922 = 1.6376207698219576
#
# Cost at iteration 923 = 1.6371962632700494
#
# Cost at iteration 924 = 1.6367718920995487
#
# Cost at iteration 925 = 1.6363476562672352
#
# Cost at iteration 926 = 1.6359235557299037
#
# Cost at iteration 927 = 1.6354995904443608
#
# Cost at iteration 928 = 1.635075760367429
#
# Cost at iteration 929 = 1.6346520654559429
#
# Cost at iteration 930 = 1.6342285056667532
#
# Cost at iteration 931 = 1.6338050809567208
#
# Cost at iteration 932 = 1.6333817912827235
#
# Cost at iteration 933 = 1.6329586366016522
#
# Cost at iteration 934 = 1.6325356168704106
#
# Cost at iteration 935 = 1.6321127320459166
#
# Cost at iteration 936 = 1.6316899820851025
#
# Cost at iteration 937 = 1.6312673669449136
#
# Cost at iteration 938 = 1.630844886582309
#
# Cost at iteration 939 = 1.6304225409542628
#
# Cost at iteration 940 = 1.6300003300177603
#
# Cost at iteration 941 = 1.6295782537298034
#
# Cost at iteration 942 = 1.6291563120474064
#
# Cost at iteration 943 = 1.628734504927596
#
# Cost at iteration 944 = 1.6283128323274156
#
# Cost at iteration 945 = 1.6278912942039194
#
# Cost at iteration 946 = 1.6274698905141778
#
# Cost at iteration 947 = 1.6270486212152728
#
# Cost at iteration 948 = 1.6266274862643015
#
# Cost at iteration 949 = 1.6262064856183744
#
# Cost at iteration 950 = 1.625785619234615
#
# Cost at iteration 951 = 1.625364887070162
#
# Cost at iteration 952 = 1.6249442890821661
#
# Cost at iteration 953 = 1.6245238252277925
#
# Cost at iteration 954 = 1.6241034954642204
#
# Cost at iteration 955 = 1.6236832997486421
#
# Cost at iteration 956 = 1.6232632380382643
#
# Cost at iteration 957 = 1.622843310290306
#
# Cost at iteration 958 = 1.6224235164620011
#
# Cost at iteration 959 = 1.6220038565105974
#
# Cost at iteration 960 = 1.6215843303933546
#
# Cost at iteration 961 = 1.6211649380675486
#
# Cost at iteration 962 = 1.6207456794904664
#
# Cost at iteration 963 = 1.620326554619411
#
# Cost at iteration 964 = 1.6199075634116966
#
# Cost at iteration 965 = 1.6194887058246532
#
# Cost at iteration 966 = 1.6190699818156233
#
# Cost at iteration 967 = 1.618651391341963
#
# Cost at iteration 968 = 1.6182329343610422
#
# Cost at iteration 969 = 1.6178146108302456
#
# Cost at iteration 970 = 1.6173964207069693
#
# Cost at iteration 971 = 1.6169783639486244
#
# Cost at iteration 972 = 1.6165604405126357
#
# Cost at iteration 973 = 1.6161426503564411
#
# Cost at iteration 974 = 1.6157249934374922
#
# Cost at iteration 975 = 1.615307469713254
#
# Cost at iteration 976 = 1.6148900791412055
#
# Cost at iteration 977 = 1.6144728216788395
#
# Cost at iteration 978 = 1.6140556972836617
#
# Cost at iteration 979 = 1.6136387059131916
#
# Cost at iteration 980 = 1.613221847524963
#
# Cost at iteration 981 = 1.6128051220765214
#
# Cost at iteration 982 = 1.6123885295254279
#
# Cost at iteration 983 = 1.6119720698292563
#
# Cost at iteration 984 = 1.6115557429455942
#
# Cost at iteration 985 = 1.6111395488320421
#
# Cost at iteration 986 = 1.6107234874462155
#
# Cost at iteration 987 = 1.6103075587457407
#
# Cost at iteration 988 = 1.6098917626882612
#
# Cost at iteration 989 = 1.60947609923143
#
# Cost at iteration 990 = 1.6090605683329178
#
# Cost at iteration 991 = 1.608645169950406
#
# Cost at iteration 992 = 1.6082299040415902
#
# Cost at iteration 993 = 1.6078147705641794
#
# Cost at iteration 994 = 1.6073997694758968
#
# Cost at iteration 995 = 1.6069849007344783
#
# Cost at iteration 996 = 1.6065701642976742
#
# Cost at iteration 997 = 1.6061555601232467
#
# Cost at iteration 998 = 1.6057410881689733
#
# Cost at iteration 999 = 1.6053267483926443
#
# Cost at iteration 1000 = 1.604912540752063
#
# [[0.28344274]
#  [0.28343981]
#  [0.28344757]
#  [0.28344901]
#  [0.28344266]
#  [0.28344677]
#  [0.2834427 ]
#  [0.28343914]
#  [0.28344297]
#  [0.28345057]
#  [0.28345429]
#  [0.28343925]
#  [0.28345749]
#  [0.28344759]
#  [0.28342241]
#  [0.28344807]
#  [0.28344972]
#  [0.28344576]
#  [0.28342315]
#  [0.28344959]
#  [0.28343807]]
